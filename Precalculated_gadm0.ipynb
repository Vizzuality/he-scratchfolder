# %% [markdown]
# # Precalculated data for gadm0
# ## Setup
# ### Library import
# We import all the required Python libraries

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import arcgis
from arcgis.gis import GIS
import json
import pandas as pd
from arcgis.features import FeatureLayerCollection
import requests as re
from copy import deepcopy
from itertools import repeat
import functools

# %% [markdown]
# ### Utils

# %% [markdown]
# **getHTfromId**

# %%
def getHTfromId(item_id):
    item = gis.content.get(item_id)
    flayer = item.tables[0]
    sdf = flayer.query().sdf
    return sdf

# %% [markdown]
# **format_df**

# %%
def format_df(path, file_name, lookups_id):
    #save_steps= np.arange(1,217486,step=5000)
    ### Loop over each set of data and add all results to one dictionary that will be a text field in the Feature Service

    df = pd.read_csv(f'{path}/{file_name}')
    # col_name = [col for col in df.columns if col in ['amphibians','birds','presence','reptiles']]
    # df.rename(columns={'SliceNumbe':'SliceNumber',col_name[0]:'SUM'}, inplace=True)

    ### Get species area against global species range:
    lookup = getHTfromId(lookups_id)
    df = df.merge(lookup[['SliceNumber','range_area_km2']], how='left',on = 'SliceNumber')
    df['per_global'] = round(df['SUM']/df['range_area_km2']*100,2)
    df.loc[df['per_global']> 100,'per_global'] = 100 ### make max presence 100%
    
    ### Get species area against aoi area:
    df = df.merge(gadm0[['MOL_ID','AREA_KM2']])
    df['per_aoi'] = round(df['SUM']/df['AREA_KM2']*100,2)
    df.loc[df['per_aoi']> 100,'per_aoi'] = 100 ### make max presence 100%
    
    return df

# %% [markdown]
# ## Connect to ArcGIS API

# %%
env_path = ".env"
with open(env_path) as f:
   env = {}
   for line in f:
       env_key, _val = line.split("=")
       env_value = _val.split("\n")[0]
       env[env_key] = env_value

# %%
aol_password = env['ARCGIS_GRETA_PASS']
aol_username = env['ARCGIS_GRETA_USER']

# %%
gis = GIS("https://eowilson.maps.arcgis.com", aol_username, aol_password, profile = "eowilson")
# Out:
# Keyring backend being used (keyring.backends.OS_X.Keyring (priority: 5)) either failed to install or is not recommended by the keyring project (i.e. it is not secure). This means you can not use stored passwords through GIS's persistent profiles. Note that extra system-wide steps must be taken on a Linux machine to use the python keyring module securely. Read more about this at the keyring API doc (http://bit.ly/2EWDP7B) and the ArcGIS API for Python doc (http://bit.ly/2CK2wG8).

# %% [markdown]
# ## Read data

# %%
path_in = '/Users/sofia/Documents/HE_Data/Precalculated/gadm0/Inputs'
path_out = '/Users/sofia/Documents/HE_Data/Precalculated/gadm0/Outputs'

# %% [markdown]
# ### gadm0

# %%
# wdpa table
gadm0= gpd.read_file(f'{path_in}/gadm36_level0_original_simple.shp')
# gadm0.rename(columns={'AREA_KM':'AREA_KM2'},inplace=True)

# %%
gadm0.head()
# Out:
#   GID_0       NAME_0      AREA_KM2  MOL_ID  InPoly_FID  SimPgnFlag  \
# 0   ABW        Aruba  1.819384e+02       1           1           0
# 1   AFG  Afghanistan  6.438575e+05       2           2           0
# 2   AGO       Angola  1.247422e+06       3           3           0
# 3   AIA     Anguilla  8.330331e+01       4           4           0
# 4   ALA        Åland  1.506261e+03       5           5           0
#
#    MaxSimpTol  MinSimpTol                                           geometry
# 0       0.005       0.005  POLYGON ((-69.97820 12.46986, -70.02847 12.503...
# 1       0.005       0.005  POLYGON ((68.52644 31.75435, 68.53852 31.75457...
# 2       0.005       0.005  MULTIPOLYGON (((11.73347 -16.67255, 11.74014 -...
# 3       0.005       0.005  MULTIPOLYGON (((-63.42375 18.58903, -63.42847 ...
# 4       0.005       0.005  MULTIPOLYGON (((21.32195 59.74986, 21.32472 59...

# %%
dff = gadm0[['GID_0','NAME_0','MOL_ID','AREA_KM2','geometry']].copy() 
dff.head()
# Out:
#   GID_0       NAME_0  MOL_ID      AREA_KM2  \
# 0   ABW        Aruba       1  1.819384e+02
# 1   AFG  Afghanistan       2  6.438575e+05
# 2   AGO       Angola       3  1.247422e+06
# 3   AIA     Anguilla       4  8.330331e+01
# 4   ALA        Åland       5  1.506261e+03
#
#                                             geometry
# 0  POLYGON ((-69.97820 12.46986, -70.02847 12.503...
# 1  POLYGON ((68.52644 31.75435, 68.53852 31.75457...
# 2  MULTIPOLYGON (((11.73347 -16.67255, 11.74014 -...
# 3  MULTIPOLYGON (((-63.42375 18.58903, -63.42847 ...
# 4  MULTIPOLYGON (((21.32195 59.74986, 21.32472 59...

# %% [markdown]
# ### gadm0's biodiversity data

# %%
### Ids of lookup tables for each taxa in ArcGIS online

lookups = {'amphibians':'c221a727e12048b2a6ec8e762bc5f478',
         'birds':'bcb31fd9091446a0af3cfdaed334a8da',
         'mammals':'212a3dd4665845deb5d2adf5b597aae0',
         'reptiles':'5b606a03b3fc431e8d4b9191c88bc2b9'}

# Get data for all taxa
amphibians = format_df(path_in, 'gadm0_amphibians.csv', lookups['amphibians'])
birds = format_df(path_in, 'gadm0_birds.csv', lookups['birds'])
mammals = format_df(path_in, 'gadm0_mammals.csv', lookups['mammals'])
reptiles = format_df(path_in, 'gadm0_reptiles.csv', lookups['reptiles'])

# %%
amphibians.head(1)
# Out:
#    OBJECTID  MOL_ID  SliceNumber  FREQUENCY    SUM  range_area_km2  \
# 0         1       1         1819          1  151.0           24981
#
#    per_global    AREA_KM2  per_aoi
# 0         0.6  181.938403     83.0

# %%
birds.head(1)
# Out:
#    OBJECTID  MOL_ID  SliceNumber  FREQUENCY   SUM  range_area_km2  per_global  \
# 0         1       1          142          1  36.0         2656221         0.0
#
#      AREA_KM2  per_aoi
# 0  181.938403    19.79

# %%
mammals.head(1)
# Out:
#    OBJECTID  MOL_ID  SliceNumber  FREQUENCY   SUM  range_area_km2  per_global  \
# 0         1       1          329          1  55.0         1173243         0.0
#
#      AREA_KM2  per_aoi
# 0  181.938403    30.23

# %%
reptiles.head(1)
# Out:
#    OBJECTID  MOL_ID  SliceNumber  FREQUENCY    SUM  range_area_km2  \
# 0         1       1          353          1  164.0         1441180
#
#    per_global    AREA_KM2  per_aoi
# 0        0.01  181.938403    90.14

# %% [markdown]
# ## Processing

# %%
amphibians = amphibians.groupby('MOL_ID')[['SliceNumber', 'per_global', 'per_aoi']].apply(lambda x: x.to_json(orient='records')).to_frame('amphibians').reset_index()
birds = birds.groupby('MOL_ID')[['SliceNumber', 'per_global', 'per_aoi']].apply(lambda x: x.to_json(orient='records')).to_frame('birds').reset_index()
mammals = mammals.groupby('MOL_ID')[['SliceNumber', 'per_global', 'per_aoi']].apply(lambda x: x.to_json(orient='records')).to_frame('mammals').reset_index()
reptiles = reptiles.groupby('MOL_ID')[['SliceNumber', 'per_global', 'per_aoi']].apply(lambda x: x.to_json(orient='records')).to_frame('reptiles').reset_index()

# %%
amphibians.head(1)
# Out:
#    MOL_ID                                         amphibians
# 0       1  [{"SliceNumber":1819,"per_global":0.6,"per_aoi...

# %%
dff = pd.merge(dff, amphibians, how='left', on = 'MOL_ID')
dff = pd.merge(dff, birds, how='left', on = 'MOL_ID')
dff = pd.merge(dff, mammals, how='left', on = 'MOL_ID')
dff = pd.merge(dff, reptiles, how='left', on = 'MOL_ID')
dff.head()
# Out:
#   GID_0       NAME_0  MOL_ID      AREA_KM2  \
# 0   ABW        Aruba       1  1.819384e+02
# 1   AFG  Afghanistan       2  6.438575e+05
# 2   AGO       Angola       3  1.247422e+06
# 3   AIA     Anguilla       4  8.330331e+01
# 4   ALA        Åland       5  1.506261e+03
#
#                                             geometry  \
# 0  POLYGON ((-69.97820 12.46986, -70.02847 12.503...
# 1  POLYGON ((68.52644 31.75435, 68.53852 31.75457...
# 2  MULTIPOLYGON (((11.73347 -16.67255, 11.74014 -...
# 3  MULTIPOLYGON (((-63.42375 18.58903, -63.42847 ...
# 4  MULTIPOLYGON (((21.32195 59.74986, 21.32472 59...
#
#                                           amphibians  \
# 0  [{"SliceNumber":1819,"per_global":0.6,"per_aoi...
# 1  [{"SliceNumber":32,"per_global":100.0,"per_aoi...
# 2  [{"SliceNumber":2,"per_global":0.59,"per_aoi":...
# 3  [{"SliceNumber":1819,"per_global":0.23,"per_ao...
# 4  [{"SliceNumber":963,"per_global":0.01,"per_aoi...
#
#                                                birds  \
# 0  [{"SliceNumber":142,"per_global":0.0,"per_aoi"...
# 1  [{"SliceNumber":26,"per_global":1.44,"per_aoi"...
# 2  [{"SliceNumber":26,"per_global":4.67,"per_aoi"...
# 3  [{"SliceNumber":142,"per_global":0.0,"per_aoi"...
# 4  [{"SliceNumber":116,"per_global":0.01,"per_aoi...
#
#                                              mammals  \
# 0  [{"SliceNumber":329,"per_global":0.0,"per_aoi"...
# 1  [{"SliceNumber":167,"per_global":11.15,"per_ao...
# 2  [{"SliceNumber":28,"per_global":2.22,"per_aoi"...
# 3  [{"SliceNumber":329,"per_global":0.0,"per_aoi"...
# 4  [{"SliceNumber":129,"per_global":0.01,"per_aoi...
#
#                                             reptiles
# 0  [{"SliceNumber":353,"per_global":0.01,"per_aoi...
# 1  [{"SliceNumber":1,"per_global":28.71,"per_aoi"...
# 2  [{"SliceNumber":40,"per_global":26.68,"per_aoi...
# 3  [{"SliceNumber":316,"per_global":25.32,"per_ao...
# 4  [{"SliceNumber":2500,"per_global":0.01,"per_ao...

# %%
dff.loc[dff['MOL_ID']==1,'birds'].values[0]
# Out:
# '[{"SliceNumber":142,"per_global":0.0,"per_aoi":19.79},{"SliceNumber":463,"per_global":0.0,"per_aoi":29.68},{"SliceNumber":466,"per_global":0.0,"per_aoi":4.95},{"SliceNumber":538,"per_global":0.0,"per_aoi":3.3},{"SliceNumber":539,"per_global":0.0,"per_aoi":1.65},{"SliceNumber":905,"per_global":0.0,"per_aoi":86.29},{"SliceNumber":970,"per_global":0.0,"per_aoi":19.79},{"SliceNumber":1099,"per_global":0.0,"per_aoi":1.1},{"SliceNumber":1179,"per_global":0.0,"per_aoi":13.74},{"SliceNumber":1302,"per_global":0.0,"per_aoi":8.79},{"SliceNumber":1306,"per_global":0.0,"per_aoi":31.88},{"SliceNumber":1309,"per_global":0.01,"per_aoi":38.47},{"SliceNumber":1310,"per_global":0.0,"per_aoi":39.57},{"SliceNumber":1312,"per_global":0.0,"per_aoi":68.15},{"SliceNumber":1314,"per_global":0.0,"per_aoi":40.12},{"SliceNumber":1449,"per_global":0.02,"per_aoi":66.51},{"SliceNumber":1599,"per_global":0.0,"per_aoi":1.1},{"SliceNumber":1680,"per_global":0.0,"per_aoi":16.49},{"SliceNumber":1774,"per_global":0.0,"per_aoi":34.63},{"SliceNumber":1779,"per_global":0.0,"per_aoi":40.67},{"SliceNumber":1798,"per_global":0.0,"per_aoi":17.04},{"SliceNumber":1802,"per_global":0.0,"per_aoi":7.69},{"SliceNumber":1803,"per_global":0.01,"per_aoi":40.67},{"SliceNumber":1848,"per_global":0.0,"per_aoi":14.29},{"SliceNumber":2156,"per_global":0.0,"per_aoi":68.15},{"SliceNumber":2173,"per_global":0.01,"per_aoi":64.86},{"SliceNumber":2233,"per_global":0.0,"per_aoi":19.24},{"SliceNumber":2255,"per_global":0.0,"per_aoi":89.59},{"SliceNumber":3031,"per_global":0.0,"per_aoi":3.85},{"SliceNumber":3045,"per_global":0.0,"per_aoi":81.9},{"SliceNumber":3116,"per_global":0.0,"per_aoi":68.15},{"SliceNumber":3407,"per_global":0.0,"per_aoi":63.76},{"SliceNumber":3424,"per_global":0.0,"per_aoi":67.61},{"SliceNumber":3550,"per_global":0.0,"per_aoi":17.04},{"SliceNumber":3560,"per_global":0.18,"per_aoi":19.79},{"SliceNumber":3985,"per_global":0.0,"per_aoi":1.1},{"SliceNumber":4351,"per_global":0.03,"per_aoi":63.76},{"SliceNumber":4357,"per_global":0.01,"per_aoi":88.49},{"SliceNumber":4582,"per_global":0.0,"per_aoi":20.34},{"SliceNumber":4595,"per_global":0.0,"per_aoi":23.63},{"SliceNumber":4606,"per_global":0.0,"per_aoi":2.75},{"SliceNumber":4693,"per_global":0.0,"per_aoi":70.9},{"SliceNumber":4762,"per_global":0.02,"per_aoi":26.93},{"SliceNumber":5610,"per_global":0.0,"per_aoi":66.51},{"SliceNumber":6000,"per_global":0.0,"per_aoi":29.68},{"SliceNumber":6044,"per_global":0.0,"per_aoi":32.43},{"SliceNumber":6053,"per_global":0.0,"per_aoi":28.58},{"SliceNumber":6167,"per_global":0.0,"per_aoi":15.94},{"SliceNumber":6169,"per_global":0.0,"per_aoi":64.86},{"SliceNumber":6375,"per_global":0.0,"per_aoi":69.8},{"SliceNumber":6387,"per_global":0.0,"per_aoi":20.34},{"SliceNumber":6508,"per_global":0.0,"per_aoi":63.76},{"SliceNumber":6533,"per_global":0.16,"per_aoi":69.8},{"SliceNumber":6562,"per_global":0.0,"per_aoi":14.84},{"SliceNumber":6712,"per_global":0.0,"per_aoi":5.5},{"SliceNumber":7275,"per_global":0.0,"per_aoi":27.48},{"SliceNumber":7292,"per_global":0.0,"per_aoi":17.59},{"SliceNumber":7421,"per_global":0.0,"per_aoi":67.61},{"SliceNumber":7775,"per_global":0.0,"per_aoi":13.74},{"SliceNumber":7892,"per_global":0.02,"per_aoi":30.23},{"SliceNumber":8260,"per_global":0.0,"per_aoi":67.61},{"SliceNumber":8446,"per_global":0.0,"per_aoi":19.79},{"SliceNumber":8566,"per_global":0.0,"per_aoi":2.2},{"SliceNumber":8567,"per_global":0.0,"per_aoi":2.75},{"SliceNumber":8573,"per_global":0.0,"per_aoi":2.2},{"SliceNumber":8574,"per_global":0.01,"per_aoi":17.04},{"SliceNumber":8577,"per_global":0.0,"per_aoi":14.84},{"SliceNumber":8579,"per_global":0.0,"per_aoi":19.79},{"SliceNumber":8582,"per_global":0.0,"per_aoi":4.4},{"SliceNumber":8586,"per_global":0.0,"per_aoi":14.84},{"SliceNumber":8679,"per_global":0.02,"per_aoi":68.7},{"SliceNumber":8684,"per_global":0.0,"per_aoi":14.29},{"SliceNumber":8686,"per_global":0.0,"per_aoi":13.19},{"SliceNumber":8688,"per_global":0.0,"per_aoi":14.29},{"SliceNumber":8784,"per_ ...

# %% [markdown]
# **Save table**

# %%
dff.to_csv((f'{path_out}/gadm0_precalculated_biodiversity_only.csv'))

# %% [markdown]
# ### Get contextual data from old table

# %%
ctx = gpd.read_file(f'{path_in}/all_precalc_gadm0.geojson')
ctx.head(1)
# Out:
#   GID_0 NAME_0  MOL_ID    AREA_KM2  \
# 0   ABW  Aruba       1  181.938403
#
#                                                birds  percentage_protected  \
# 0  [ { "SliceNumber": 142.0, "percentage_presence...             20.609302
#
#    population_sum  majority_land_cover_climate_regime land_cover_majority  \
# 0   115656.129532                               335.0           Shrubland
#
#   climate_regime_majority  country_size  percent_irrigated  percent_rainfed  \
# 0            Tropical Dry             5                NaN            24.66
#
#    percent_rangeland  percent_urban  \
# 0                NaN           6.39
#
#                                             geometry
# 0  POLYGON ((-69.97820 12.46986, -70.02847 12.503...

# %%
ctx2 = ctx[['MOL_ID','percentage_protected','population_sum','majority_land_cover_climate_regime', 'land_cover_majority','climate_regime_majority',
            'percent_irrigated', 'percent_rainfed','percent_rangeland', 'percent_urban','country_size']].copy()

# %%
ctx2.head()
# Out:
#    MOL_ID  percentage_protected  population_sum  \
# 0       1             20.609302    1.156561e+05
# 1       2              3.785337    3.038970e+07
# 2       3              6.679349    3.607495e+07
# 3       4              2.880000    1.360196e+04
# 4       5              1.449518    2.915896e+04
#
#    majority_land_cover_climate_regime land_cover_majority  \
# 0                               335.0           Shrubland
# 1                               142.0           Grassland
# 2                               268.0              Forest
# 3                               393.0           Grassland
# 4                               111.0              Forest
#
#   climate_regime_majority  percent_irrigated  percent_rainfed  \
# 0            Tropical Dry                NaN            24.66
# 1      Cool Temperate Dry               6.48            18.49
# 2      Sub Tropical Moist               0.07             4.19
# 3          Tropical Moist                NaN              NaN
# 4    Cool Temperate Moist                NaN            50.27
#
#    percent_rangeland  percent_urban  country_size
# 0                NaN           6.39             5
# 1              62.15           0.07             3
# 2              67.89           0.08             2
# 3                NaN            NaN             5
# 4                NaN            NaN             5

# %% [markdown]
# ### Merge contextual data to WDPA dataframe

# %%
dff2 = pd.merge(dff, ctx2, how='left', on = 'MOL_ID')
dff2.head()
# Out:
#   GID_0       NAME_0  MOL_ID      AREA_KM2  \
# 0   ABW        Aruba       1  1.819384e+02
# 1   AFG  Afghanistan       2  6.438575e+05
# 2   AGO       Angola       3  1.247422e+06
# 3   AIA     Anguilla       4  8.330331e+01
# 4   ALA        Åland       5  1.506261e+03
#
#                                             geometry  \
# 0  POLYGON ((-69.97820 12.46986, -70.02847 12.503...
# 1  POLYGON ((68.52644 31.75435, 68.53852 31.75457...
# 2  MULTIPOLYGON (((11.73347 -16.67255, 11.74014 -...
# 3  MULTIPOLYGON (((-63.42375 18.58903, -63.42847 ...
# 4  MULTIPOLYGON (((21.32195 59.74986, 21.32472 59...
#
#                                           amphibians  \
# 0  [{"SliceNumber":1819,"per_global":0.6,"per_aoi...
# 1  [{"SliceNumber":32,"per_global":100.0,"per_aoi...
# 2  [{"SliceNumber":2,"per_global":0.59,"per_aoi":...
# 3  [{"SliceNumber":1819,"per_global":0.23,"per_ao...
# 4  [{"SliceNumber":963,"per_global":0.01,"per_aoi...
#
#                                                birds  \
# 0  [{"SliceNumber":142,"per_global":0.0,"per_aoi"...
# 1  [{"SliceNumber":26,"per_global":1.44,"per_aoi"...
# 2  [{"SliceNumber":26,"per_global":4.67,"per_aoi"...
# 3  [{"SliceNumber":142,"per_global":0.0,"per_aoi"...
# 4  [{"SliceNumber":116,"per_global":0.01,"per_aoi...
#
#                                              mammals  \
# 0  [{"SliceNumber":329,"per_global":0.0,"per_aoi"...
# 1  [{"SliceNumber":167,"per_global":11.15,"per_ao...
# 2  [{"SliceNumber":28,"per_global":2.22,"per_aoi"...
# 3  [{"SliceNumber":329,"per_global":0.0,"per_aoi"...
# 4  [{"SliceNumber":129,"per_global":0.01,"per_aoi...
#
#                                             reptiles  percentage_protected  \
# 0  [{"SliceNumber":353,"per_global":0.01,"per_aoi...             20.609302
# 1  [{"SliceNumber":1,"per_global":28.71,"per_aoi"...              3.785337
# 2  [{"SliceNumber":40,"per_global":26.68,"per_aoi...              6.679349
# 3  [{"SliceNumber":316,"per_global":25.32,"per_ao...              2.880000
# 4  [{"SliceNumber":2500,"per_global":0.01,"per_ao...              1.449518
#
#    population_sum  majority_land_cover_climate_regime land_cover_majority  \
# 0    1.156561e+05                               335.0           Shrubland
# 1    3.038970e+07                               142.0           Grassland
# 2    3.607495e+07                               268.0              Forest
# 3    1.360196e+04                               393.0           Grassland
# 4    2.915896e+04                               111.0              Forest
#
#   climate_regime_majority  percent_irrigated  percent_rainfed  \
# 0            Tropical Dry                NaN            24.66
# 1      Cool Temperate Dry               6.48            18.49
# 2      Sub Tropical Moist               0.07             4.19
# 3          Tropical Moist                NaN              NaN
# 4    Cool Temperate Moist                NaN            50.27
#
#    percent_rangeland  percent_urban  country_size
# 0                NaN           6.39             5
# 1              62.15           0.07             3
# 2              67.89           0.08             2
# 3                NaN            NaN             5
# 4                NaN            NaN             5

# %%
dff2.to_file('/Users/sofia/Documents/HE_Data/Precalculated/gadm0/Outputs/gadm0_precalculated_20220224.geojson',driver='GeoJSON')

# %%
gadm1= pd.read_csv('/Users/sofia/Documents/HE_Data/Precalculated/gadm1/')
