# %% [markdown]
# # Making a function to add fields to the service

# %%
import arcgis
from arcgis.gis import GIS, GroupManager
from arcgis.features import FeatureLayerCollection
from arcgis.features import FeatureLayer
from copy import deepcopy
from arcgis import geometry
import re
from pprint import pprint
import pandas as pd

# %%
env_path = ".env"
with open(env_path) as f:
    env = {}
    for line in f:
        env_key, _val = line.split("=")
        env_value = _val.split("\n")[0]
        env[env_key] = env_value

# %%
aol_password = env['aol_key']
aol_username = env['aol_username']

# %%
#gis = GIS("https://eowilson.maps.arcgis.com", aol_username, aol_password, profile = "eowilson")

# %%
gis = GIS(profile = "eowilson")

# %%
def create_strict_reg_exp(to_search):
    try:
        reg_exp = f"^{to_search}$"
        #logging.info(f"regular expression is: {reg_exp}")
    except:
        print("There was a problem with the string.")
    return reg_exp

# %%
def findItemGetID(csvName, gis):
    try:
        searched_item = gis.content.search(csvName, item_type = "Feature Layer")
        for i in searched_item:
            reg_exp = create_strict_reg_exp(csvName)
            if re.search(reg_exp, i.title)!= None:    
                #logging.info(f"{csvName} has the id: {i.id}")
                return i.id
    except:
        print("There was a problem finding the item")

# %%
def getFlayerFromID(item_id):
    item = gis.content.get(item_id)
    flayer = item.layers[0]
    return flayer

# %%
def getSDFfromFlayer(flayer):
    sdf = pd.DataFrame.spatial.from_layer(flayer)
    return sdf

# %%
def createFieldsToBeAdded(flayer, csv_table):
    flayer_fields = flayer.manager.properties.fields
    template_field = dict(deepcopy(flayer_fields[0]))
    sdf = getSDFfromFlayer(flayer)
    new_field_names = list(csv_table.columns.difference(sdf.columns))
    
    fields_to_be_added = []
    for new_field_name in new_field_names:
        current_field = deepcopy(template_field)
        dt = csv_table[new_field_name].dtypes
        
        if dt == 'O':
            #put the type to character
            current_field['sqlType'] = 'sqlTypeOther'
            current_field['type'] = 'esriFieldTypeString'
            #current_field['length'] = 8000
        if dt == 'float64':
            #put the type to double
            current_field['sqlType'] = 'sqlTypeOther'
            current_field['type'] = 'esriFieldTypeDouble'
            #current_field['length'] = 8000      

        current_field['name'] = new_field_name.lower()
        current_field['alias'] = new_field_name
        current_field['nullable'] = True
        current_field['editable'] = True
        fields_to_be_added.append(current_field)
    return fields_to_be_added

# %%
def createFeaturesForUpdate(flayer, csv_table, fields_to_be_added, id_field_in_csv, id_field_in_service):
    fset2 = flayer.query()
    features2 = fset2.features
    features_for_update = []
    for country_id in csv_table[id_field_in_csv]:
        try:
            # get the matching row from csv
            matching_row = csv_table.where(csv_table[id_field_in_csv] == country_id).dropna()

            #print(str(country_id) + " Adding additional attributes for: " + matching_row['iso3'].values[0])

            # get the feature to be updated
            assert  len([f for f in features2 if f.attributes[id_field_in_service] == country_id]),  "id not matched"
            original_feature = [f for f in features2 if f.attributes[id_field_in_service] == country_id][0]
            feature_to_be_updated = deepcopy(original_feature)

            # assign the updated values
            for field in fields_to_be_added:
                feature_to_be_updated.attributes[field['name']] = matching_row[field['name']].values[0]
                #add this to the list of features to be updated
                features_for_update.append(feature_to_be_updated)
            #print(str(country_id) + " Done additional attributes for: " + matching_row['countryname'].values[0])
    
        except:
            print(f"{country_id} not available in service")
    return features_for_update

# %%
item_id = findItemGetID("gadm_centroid", gis)

# %%
flayer = getFlayerFromID(item_id)

# %%
csv_table_all = pd.read_csv("/Users/gretacvega/Documents/GitHub/vizzWork/MOL/gid_continent.csv")

# %%
csv_table = csv_table_all[['GID_0', 'continent']]

# %% [markdown]
# #### It is better if all the field names are lower case because otherwise the alias will have caps and the name won't which will make it tricky for the final function.

# %%
fields_to_be_added = createFieldsToBeAdded(flayer, csv_table)

# %%
fields_to_be_added
# Out:
# [{'name': 'continent',
#   'type': 'esriFieldTypeString',
#   'alias': 'continent',
#   'sqlType': 'sqlTypeOther',
#   'nullable': True,
#   'editable': True,
#   'visible': True,
#   'domain': None,
#   'defaultValue': None}]

# %%
flayer.manager.add_to_definition({'fields':fields_to_be_added})
# Out:
# {'success': True}

# %%
features_for_update = createFeaturesForUpdate(flayer, csv_table, fields_to_be_added, id_field_in_csv = "GID_0", id_field_in_service = "GID_0")
# Out:
# IOT not available in service
# UMI not available in service

# %%
flayer.edit_features(updates= features_for_update)
# Out:
# {'addResults': [],
#  'updateResults': [{'objectId': 1,
#    'uniqueId': 1,
#    'globalId': 'fe9f6eb0-f4f8-4f29-875a-5cbb3219e4e5',
#    'success': True},
#   {'objectId': 2,
#    'uniqueId': 2,
#    'globalId': '193ba976-0e5a-4cf6-9b09-d00bf83f4557',
#    'success': True},
#   {'objectId': 3,
#    'uniqueId': 3,
#    'globalId': '174ce788-4f67-4ae0-922f-d2ddac87f8c3',
#    'success': True},
#   {'objectId': 4,
#    'uniqueId': 4,
#    'globalId': '9f5f24d8-8b21-49a8-8f55-90b47cf63e7b',
#    'success': True},
#   {'objectId': 5,
#    'uniqueId': 5,
#    'globalId': '2b45351b-a335-490e-914e-7748d4f41f66',
#    'success': True},
#   {'objectId': 6,
#    'uniqueId': 6,
#    'globalId': '238963fe-66f4-49b3-ac6b-5ac57aade444',
#    'success': True},
#   {'objectId': 7,
#    'uniqueId': 7,
#    'globalId': '1c57acd6-8014-4086-8fdf-0c2476600d9c',
#    'success': True},
#   {'objectId': 8,
#    'uniqueId': 8,
#    'globalId': '63d38719-32e2-40d0-8d5a-2d84dd7bc2d3',
#    'success': True},
#   {'objectId': 9,
#    'uniqueId': 9,
#    'globalId': '0453843e-4d99-4fc8-b4ca-5b37eeea2c2d',
#    'success': True},
#   {'objectId': 10,
#    'uniqueId': 10,
#    'globalId': '266ca8f7-1347-41e8-b341-062958166410',
#    'success': True},
#   {'objectId': 11,
#    'uniqueId': 11,
#    'globalId': 'aaa034b5-dc49-486a-92bf-983078e2f61a',
#    'success': True},
#   {'objectId': 12,
#    'uniqueId': 12,
#    'globalId': '31d4f242-3c5b-4e94-bc65-e288880d9dda',
#    'success': True},
#   {'objectId': 13,
#    'uniqueId': 13,
#    'globalId': '3fc7e6c9-dbc2-4c37-b09a-947f046237eb',
#    'success': True},
#   {'objectId': 14,
#    'uniqueId': 14,
#    'globalId': 'ecb3b16c-4948-4d54-b425-a9b30debeeb6',
#    'success': True},
#   {'objectId': 15,
#    'uniqueId': 15,
#    'globalId': '1834e802-3244-4ae2-8bad-b16b7d8bf3fa',
#    'success': True},
#   {'objectId': 16,
#    'uniqueId': 16,
#    'globalId': '235f7037-9584-45e5-92bc-b96f6fb1cac0',
#    'success': True},
#   {'objectId': 17,
#    'uniqueId': 17,
#    'globalId': '70d62dd9-7c12-4e9d-812b-32fc4e22faa1',
#    'success': True},
#   {'objectId': 18,
#    'uniqueId': 18,
#    'globalId': '706f7885-c7be-4e6e-a57a-8fbd59fe8019',
#    'success': True},
#   {'objectId': 19,
#    'uniqueId': 19,
#    'globalId': '4682b992-1033-4c6f-8d35-f3b1fe0671e6',
#    'success': True},
#   {'objectId': 20,
#    'uniqueId': 20,
#    'globalId': 'ac368d7b-73a0-415c-ba94-cbc9126b9b37',
#    'success': True},
#   {'objectId': 21,
#    'uniqueId': 21,
#    'globalId': '32708093-e1ab-4de5-a812-40d97b7eb1bb',
#    'success': True},
#   {'objectId': 22,
#    'uniqueId': 22,
#    'globalId': '796d0533-0949-4291-afa4-7f839b7b6042',
#    'success': True},
#   {'objectId': 23,
#    'uniqueId': 23,
#    'globalId': '36338fcd-b4a1-4559-b3c7-c6527673871f',
#    'success': True},
#   {'objectId': 24,
#    'uniqueId': 24,
#    'globalId': 'f5412e2a-4596-45eb-bb5a-4d41f7ab0f20',
#    'success': True},
#   {'objectId': 25,
#    'uniqueId': 25,
#    'globalId': '31946c78-0b11-4005-8519-73dc2a6073f8',
#    'success': True},
#   {'objectId': 26,
#    'uniqueId': 26,
#    'globalId': '6bf0b09e-cae9-4a79-9063-f510a658e3c3',
#    'success': True},
#   {'objectId': 27,
#    'uniqueId': 27,
#    'globalId': '174e762f-8587-4d08-bb85-ec539fd3752d',
#    'success': True},
#   {'objectId': 28,
#    'uniqueId': 28,
#    'globalId': '25745b33-e5d4-4e43-8fb2-a796e4d261c4',
#    'success': True},
#   {'objectId': 29,
#    'uniqueId': 29,
#    'globalId': '51365a5a-2a2b-4591-bbc8-66e305361568',
#    'success': True},
#   {'objectId': 30,
#    'uniqueId': 30,
#    'globalId': '05093b30-d7cb-4a29-9c57-ffdcf5e57287',
#    'success': True},
#   {'objectId': 31,
#    'uniqueId': 31,
#    'globalId': '1ef92e21-60fe-4475-b1b1-021937d93bd0',
#    'success': True},
#   {'objectId': 32,
#    'uniqueId': 32,
#    'globalId': 'e5ebfce6-0202-477f-986c-9cfb73782386',
#    'success': True},
#   {'objectId': 33,
#    'uniqueId': 33,
#    'globalId': 'd5ff501e-2a74-4d63-a695-eb37f8cf8719',
#    'success': True},
#   {'objectId': 34,
#    'uniqueId': 34,
#    'globalId': '3004b7de-06ac-46ab-b3b2-6af4c300ab80',
#    'success': True},
#   {'objectId': 35,
#    'uniqueId': 35,
#    'globalId': 'f62388b8-43bf-4716-aaae-a0d7de5ed992',
#    'success': True},
#   {'objectId': 36,
#    'uniqueId': 36,
#    'globalId': '4b727d9f-7052-4057-ac74-f0ef69fef73c',
#    'success': True},
#   {'objectId': 37,
#    'uniqueId': 37,
#    'globalId': '98c61c70-f604-4fba-942c-fce36e187be6',
#    'success': True},
#   {'objectId': 38,
#    'uniqueId': 38,
#    'globalId': '9e558460-451b-4ffd-823a-edec39f156d1',
#    'success': True},
#   {'objectId': 39,
#    'uniqueId': 39,
#    'globalId': 'ab6d8f01-c7b7-4dcd-a497-985794414e73',
#    'success': True},
#   {'objectId': 40,
#    'uniqueId': 40,
#    'globalId': '00e6357d-a633-4c3c-b8cf-318e7f63339a',
#    'success': True},
#   {'objectId': 41,
#    'uniqueId': 41,
#    'globalId': '66165570-9dda-43b4-8f3e-ed0f8c2bd38f',
#    'success': True},
#   {'objectId': 42,
#    'uniqueId': 42,
#    'globalId': '39636158-9eb8-4ae0-acba-ececed481041',
#    'success': True},
#   {'objectId': 43,
#    'uniqueId': 43,
#    'globalId': 'bc5dd499-1d1f-4bf1-96d4-a9a48da654c4',
#    'success': True},
#   {'objectId': 44,
#    'uniqueId': 44,
#    'globalId': 'a3df5b38-c3a2-4223-8442-4559e9393eec',
#    'success': True},
#   {'objectId': 45,
#    'uniqueId': 45,
#    'globalId': '7025306c-a646-4d34-99c4-e39e0ffc98ef',
#    'success': True},
#   {'objectId': 46,
#    'uniqueId': 46,
#    'globalId': 'f738b009-2838-431b-ab42-31e06e1f3011',
#    'success': True},
#   {'objectId': 47,
#    'uniqueId': 47,
#    'globalId': 'a2c0b134-662f-433a-9b78-05c15a15a0e1',
#    'success': True},
#   {'objectId': 48,
#    'uniqueId': 48,
#    'globalId': 'ac2eba6d-6495-4cdc-a223-67ef6292e92c',
#    'success': True},
#   {'objectId': 49,
#    'uniqueId': 49,
#    'globalId': 'e412b775-d873-4c7d-b18a-b22fa400b895',
#    'success': True},
#   {'objectId': 50,
#    'uniqueId': 50,
#    'globalId': 'aaf39fe0-a072-48f6-9bb1-5c5bd1c870d1',
#    'success': True},
#   {'objectId': 51,
#    'uniqueId': 51,
#    'globalId': '7b10595e-8e8f-483a-b9e2-fcbc823a72d4',
#    'success': True},
#   {'objectId': 52,
#    'uniqueId': 52,
#    'globalId': '48a8ce2a-e17c-4a66-8f8d-999fb88184f0',
#    'success': True},
#   {'objectId': 53,
#    'uniqueId': 53,
#    'globalId': 'ff22c8fd-0267-40dc-a665-1f6514afab36',
#    'success': True},
#   {'objectId': 54,
#    'uniqueId': 54,
#    'globalId': '50d369c2-5be9-4423-a378-d51721c8a4a0',
#    'success': True},
#   {'objectId': 55,
#    'uniqueId': 55,
#    'globalId': 'ebd742b1-c061-4a1f-af1e-6c0401fa680f',
#    'success': True},
#   {'objectId': 56,
#    'uniqueId': 56,
#    'globalId': '79bc7a4a-8515-4cfe-8902-946d6e50c281',
#    'success': True},
#   {'objectId': 57,
#    'uniqueId': 57,
#    'globalId': 'a83518e0-d58a-4cce-8415-65dc37efbe73',
#    'success': True},
#   {'objectId': 58,
#    'uniqueId': 58,
#    'globalId': 'bfac3dc4-7cda-4516-b9bc-bb04d49b7f50',
#    'success': True},
#   {'objectId': 59,
#    'uniqueId': 59,
#    'globalId': '587e3fd5-7406-4ef8-a0c7-ddb8294f0a49',
#    'success': True},
#   {'objectId': 60,
#    'uniqueId': 60,
#    'globalId': 'cc568316-b811-41bd-964a-d79397c1f5b5',
#    'success': True},
#   {'objectId': 61,
#    'uniqueId': 61,
#    'globalId': 'c669a0a6-7855-4690-a01e-5cce09fd0576',
#    'success': True},
#   {'objectId': 62,
#    'uniqueId': 62,
#    'globalId': '95432a51-7af3-4eb6-bf8f-eba744a55bb4',
#    'success': True},
#   {'objectId': 63,
#    'uniqueId': 63,
#    'globalId': '50b88278-4a0e-47a7-89d5-fe937c9eb6d8',
#    'success': True},
#   {'objectId': 64,
#    'uniqueId': 64,
#    'globalId': '839315a0-b9c8-43ae-8e41-83019de778dc',
#    'success': True},
#   {'objectId': 65,
#    'uniqueId': 65,
#    'globalId': 'ed31aa41-9a8d-4422-88da-0731b9e061b8',
#    'success': True},
#   {'objectId': 66,
#    'uniqueId': 66,
#    'globalId': '49f36374-7a09-46fb-a9f6-50cc6233008c',
#    'success': True},
#   {'objectId': 67,
#    'uniqueId': 67,
#    'globalId': 'b0c4538e-5a9d-4eb5-ab31-221699f11b9d',
#    'success': True},
#   {'objectId': 68,
#    'uniqueId': 68,
#    'globalId': '5ae57514-8c3f-4114-b75b-fd0d4f110bb8',
#    'success': True},
#   {'objectId': 69,
#    'uniqueId': 69,
#    'globalId': 'a4d3f910-3f2f-4ccd-87cf-60ad91ee020a',
#    'success': True},
#   {'objectId': 70,
#    'uniqueId': 70,
#    'globalId': 'b4520ff1-a7c7-4e6b-807b-5326dc212ba0',
#    'success': True},
#   {'objectId': 71,
#    'uniqueId': 71,
#    'globalId': '231432ef-c5ed-4065-b64b-48cee9c6dc71',
#    'success': True},
#   {'objectId': 72,
#    'uniqueId': 72,
#    'globalId': 'cb075f4b-fbcd-409f-83d3-7465a6b6ae95',
#    'success': True},
#   {'objectId': 73,
#    'uniqueId': 73,
#    'globalId': 'a1e87f66-f7bd-4cbe-8692-bf53f1771946',
#    'success': True},
#   {'objectId': 74,
#    'uniqueId': 74,
#    'globalId': '52b51f88-742b-4a5d-9c3d-8ab95abc9541',
#    'success': True},
#   {'objectId': 75,
#    'uniqueId': 75,
#    'globalId': '0bad7ccb-ffa9-45ef-b49f-a647a925341e',
#    'success': True},
#   {'objectId': 76,
#    'uniqueId': 76,
#    'globalId': '654d919f-79fe-4cf6-8d2c-65808d4cc323',
#    'success': True},
#   {'objectId': 77,
#    'uniqueId': 77,
#    'globalId': '40147e14-4edf-4383-8399-7b5c9d3fc79a',
#    'success': True},
#   {'objectId': 78,
#    'uniqueId': 78,
#    'globalId': '196aedf8-d335-4dbc-ad97-2ab0e7037195',
#    'success': True},
#   {'objectId': 79,
#    'uniqueId': 79,
#    'globalId': '143ccd86-6e26-414c-9149-36b37e0e9823',
#    'success': True},
#   {'objectId': 80,
#    'uniqueId': 80,
#    'globalId': '770a27af-295c-4a28-a781-ddb611c80379',
#    'success': True},
#   {'objectId': 81,
#    'uniqueId': 81,
#    'globalId': 'e2bc1d4e-4801-49cd-a22a-09c548b0fb4b',
#    'success': True},
#   {'objectId': 82,
#    'uniqueId': 82,
#    'globalId': '789f0fb5-368e-4dab-a624-6acd83157d17',
#    'success': True},
#   {'objectId': 83,
#    'uniqueId': 83,
#    'globalId': '8fe6a224-c44a-4990-b778-97132a06b6c9',
#    'success': True},
#   {'objectId': 84,
#    'uniqueId': 84,
#    'globalId': '50f28b21-1658-425a-85f6-9ab8deaec909',
#    'success': True},
#   {'objectId': 85,
#    'uniqueId': 85,
#    'globalId': '9da400cd-5291-468f-a3d5-8b3656563e23',
#    'success': True},
#   {'objectId': 86,
#    'uniqueId': 86,
#    'globalId': '8478faa3-a366-4182-bffd-2b3d24c3220b',
#    'success': True},
#   {'objectId': 87,
#    'uniqueId': 87,
#    'globalId': 'abee1d81-607c-40b9-b4cb-d17d657256db',
#    'success': True},
#   {'objectId': 88,
#    'uniqueId': 88,
#    'globalId': 'cd2d99f0-5f8f-46e0-875f-baf83c14b0ad',
#    'success': True},
#   {'objectId': 89,
#    'uniqueId': 89,
#    'globalId': '1ca45238-8c81-4e73-bfd1-597a5a2d2049',
#    'success': True},
#   {'objectId': 90,
#    'uniqueId': 90,
#    'globalId': 'e622c880-3180-4ae8-aa91-513aa2005ddb',
#    'success': True},
#   {'objectId': 91,
#    'uniqueId': 91,
#    'globalId': 'adb9fa65-b811-4596-be31-98c52e00e183',
#    'success': True},
#   {'objectId': 92,
#    'uniqueId': 92,
#    'globalId': 'b402771f-5fc9-481f-bcba-3d3eb55b0066',
#    'success': True},
#   {'objectId': 93,
#    'uniqueId': 93,
#    'globalId': 'f4d8a394-fcca-404e-acf6-80751d6b90bf',
#    'success': True},
#   {'objectId': 94,
#    'uniqueId': 94,
#    'globalId': '5f4283eb-c31e-401d-9497-313fc6528ee8',
#    'success': True},
#   {'objectId': 95,
#    'uniqueId': 95,
#    'globalId': '3cc4e971-c5e7-4d1a-83e8-c3d76ba8f5d3',
#    'success': True},
#   {'objectId': 96,
#    'uniqueId': 96,
#    'globalId': '9e1af03c-59b1-499c-9e25-6baa41c5dbbc',
#    'success': True},
#   {'objectId': 97,
#    'uniqueId': 97,
#    'globalId': '6983467c-88e2-4d00-9dca-468abb25af70',
#    'success': True},
#   {'objectId': 98,
#    'uniqueId': 98,
#    'globalId': 'a9dcb64f-4c36-4d28-bed8-5f8c0db6a65f',
#    'success': True},
#   {'objectId': 99,
#    'uniqueId': 99,
#    'globalId': 'a4e53d86-f95e-4be7-b9d4-d1d4f9e6bf45',
#    'success': True},
#   {'objectId': 100,
#    'uniqueId': 100,
#    'globalId': 'd388fbea-65df-4021-8cda-8be166e1bb0a',
#    'success': True},
#   {'objectId': 101,
#    'uniqueId': 101,
#    'globalId': '509669bf-e6ad-4288-94fc-5a8c323e6652',
#    'success': True},
#   {'objectId': 102,
#    'uniqueId': 102,
#    'globalId': '1fa3b15d-9d3c-456c-a5b8-d095a352c0ac',
#    'success': True},
#   {'objectId': 103,
#    'uniqueId': 103,
#    'globalId': '21b007d6-9cf5-4479-b6d4-fbda8a052867',
#    'success': True},
#   {'objectId': 104,
#    'uniqueId': 104,
#    'globalId': '7c8c0e90-3b07-4826-8d41-f6e9d20cb714',
#    'success': True},
#   {'objectId': 105,
#    'uniqueId': 105,
#    'globalId': 'a11d9f3f-fd86-414e-948b-a11a5d3eb228',
#    'success': True},
#   {'objectId': 106,
#    'uniqueId': 106,
#    'globalId': '13a981b7-2dc5-4774-b673-5d6ee801a11f',
#    'success': True},
#   {'objectId': 107,
#    'uniqueId': 107,
#    'globalId': 'fe9cf6fb-17ac-47d8-a8a6-7730d2f219e0',
#    'success': True},
#   {'objectId': 108,
#    'uniqueId': 108,
#    'globalId': '553d6a73-58fd-4d3d-824e-9662019ada74',
#    'success': True},
#   {'objectId': 109,
#    'uniqueId': 109,
#    'globalId': '3ec0e5aa-a0d1-4ef0-9eba-1d14f8197a15',
#    'success': True},
#   {'objectId': 110,
#    'uniqueId': 110,
#    'globalId': 'e7310ea9-7ec7-4006-8d55-b33eae024f15',
#    'success': True},
#   {'objectId': 111,
#    'uniqueId': 111,
#    'globalId': 'b81cf155-4d29-4a58-a321-d673204036b5',
#    'success': True},
#   {'objectId': 112,
#    'uniqueId': 112,
#    'globalId': 'e8581dc2-59de-4b0e-adf3-66c06900ce20',
#    'success': True},
#   {'objectId': 113,
#    'uniqueId': 113,
#    'globalId': '41f37ba1-ef13-443c-a2ef-dbc8a3a32c5a',
#    'success': True},
#   {'objectId': 114,
#    'uniqueId': 114,
#    'globalId': '6d09f280-92a0-4983-b53c-2657d45a869c',
#    'success': True},
#   {'objectId': 115,
#    'uniqueId': 115,
#    'globalId': '293f4032-b94a-4074-8ca1-4242dfd7322a',
#    'success': True},
#   {'objectId': 116,
#    'uniqueId': 116,
#    'globalId': '5786e092-6619-4e80-a592-5ee4104d1e29',
#    'success': True},
#   {'objectId': 117,
#    'uniqueId': 117,
#    'globalId': '9ca42daa-c6aa-41ed-b2bc-9928ae948849',
#    'success': True},
#   {'objectId': 118,
#    'uniqueId': 118,
#    'globalId': '203ceded-72a9-4131-9129-fe8bddaaa85b',
#    'success': True},
#   {'objectId': 119,
#    'uniqueId': 119,
#    'globalId': 'b59dbcc5-aa5a-44e4-bebf-220119d592bc',
#    'success': True},
#   {'objectId': 120,
#    'uniqueId': 120,
#    'globalId': '66b06090-9d4a-4a8e-8715-68fc12b14f30',
#    'success': True},
#   {'objectId': 250,
#    'uniqueId': 250,
#    'globalId': '6ad6905d-528c-48ca-a1e0-f176a7fa16df',
#    'success': True},
#   {'objectId': 121,
#    'uniqueId': 121,
#    'globalId': 'ab4ba15c-b153-46c7-af43-7329a0d4fd6f',
#    'success': True},
#   {'objectId': 122,
#    'uniqueId': 122,
#    'globalId': '117621a6-c21c-495b-9b7a-166db11bb1db',
#    'success': True},
#   {'objectId': 123,
#    'uniqueId': 123,
#    'globalId': '8d1480cf-628d-487a-b562-1392b9e4fabd',
#    'success': True},
#   {'objectId': 124,
#    'uniqueId': 124,
#    'globalId': '87a8baf8-082a-474e-bdf9-dd8d2cb40250',
#    'success': True},
#   {'objectId': 125,
#    'uniqueId': 125,
#    'globalId': '50f825c2-d04a-4fb1-88d9-8383f527826a',
#    'success': True},
#   {'objectId': 126,
#    'uniqueId': 126,
#    'globalId': '4a384687-ec05-40a8-93de-56ab55cdf1bd',
#    'success': True},
#   {'objectId': 127,
#    'uniqueId': 127,
#    'globalId': '8e36566a-4e44-493a-ac45-6113c9c9a8ae',
#    'success': True},
#   {'objectId': 128,
#    'uniqueId': 128,
#    'globalId': '80f420a3-becd-4d46-9fb9-d9da7a6363f9',
#    'success': True},
#   {'objectId': 129,
#    'uniqueId': 129,
#    'globalId': 'd891aa4a-54ab-418c-920d-42f2912c2306',
#    'success': True},
#   {'objectId': 130,
#    'uniqueId': 130,
#    'globalId': '1dd44435-cb2a-4100-9432-660ed92f523e',
#    'success': True},
#   {'objectId': 131,
#    'uniqueId': 131,
#    'globalId': '8ca7ff2e-a524-4c67-82a3-500b40c06751',
#    'success': True},
#   {'objectId': 132,
#    'uniqueId': 132,
#    'globalId': '8b83ab93-6553-4f18-8891-c561a6ecf7e2',
#    'success': True},
#   {'objectId': 133,
#    'uniqueId': 133,
#    'globalId': '0d248f83-651b-429d-8b80-1a0cf7bb6903',
#    'success': True},
#   {'objectId': 134,
#    'uniqueId': 134,
#    'globalId': '78bf02bd-9891-435d-9ec9-5c6036bbd49a',
#    'success': True},
#   {'objectId': 135,
#    'uniqueId': 135,
#    'globalId': '552ae9ce-ecc5-449b-a8b8-5c1d3fa7f142',
#    'success': True},
#   {'objectId': 136,
#    'uniqueId': 136,
#    'globalId': 'cfdf267e-d20f-4307-914d-388ca697e728',
#    'success': True},
#   {'objectId': 137,
#    'uniqueId': 137,
#    'globalId': '446873b1-bf31-48b3-afaa-e7ca23e05e95',
#    'success': True},
#   {'objectId': 138,
#    'uniqueId': 138,
#    'globalId': '4e0f5eb0-57b7-48da-a08e-0727265d5404',
#    'success': True},
#   {'objectId': 139,
#    'uniqueId': 139,
#    'globalId': '84ed92cb-d823-4047-b823-b3f5ccbd8a4a',
#    'success': True},
#   {'objectId': 140,
#    'uniqueId': 140,
#    'globalId': 'c1823cff-57a3-46cb-a031-cfc937aa006a',
#    'success': True},
#   {'objectId': 141,
#    'uniqueId': 141,
#    'globalId': 'dc70a3d1-3d15-4cea-aa6e-7b6d87b1ffdc',
#    'success': True},
#   {'objectId': 142,
#    'uniqueId': 142,
#    'globalId': '0093fe1b-f320-42f5-92c3-acba7bd279b9',
#    'success': True},
#   {'objectId': 143,
#    'uniqueId': 143,
#    'globalId': 'a91b735b-a536-4e1b-986c-216193540ac1',
#    'success': True},
#   {'objectId': 144,
#    'uniqueId': 144,
#    'globalId': '5c6dc833-d2e9-4c13-ab20-27a40a6a32a0',
#    'success': True},
#   {'objectId': 145,
#    'uniqueId': 145,
#    'globalId': '829909e4-d61f-492e-bb80-86ecd8cc3dca',
#    'success': True},
#   {'objectId': 146,
#    'uniqueId': 146,
#    'globalId': 'c2b4a3d2-e217-4d7b-ba40-4a0ea69f66ab',
#    'success': True},
#   {'objectId': 147,
#    'uniqueId': 147,
#    'globalId': 'bddbfd2f-9258-4136-bd8e-915bd5f68181',
#    'success': True},
#   {'objectId': 148,
#    'uniqueId': 148,
#    'globalId': 'd21e5a41-ef1f-4ec6-a66f-7e9163d90db9',
#    'success': True},
#   {'objectId': 149,
#    'uniqueId': 149,
#    'globalId': '496d19a7-4d21-41f0-9f00-883b3d49ea7e',
#    'success': True},
#   {'objectId': 150,
#    'uniqueId': 150,
#    'globalId': '1a682fb9-aac7-4912-8e2d-7b2d459513bd',
#    'success': True},
#   {'objectId': 151,
#    'uniqueId': 151,
#    'globalId': 'beabd947-1d5e-4dc0-8ef1-2e932a35ae36',
#    'success': True},
#   {'objectId': 152,
#    'uniqueId': 152,
#    'globalId': '079d9a92-b19d-472c-97c8-05b512f68bcb',
#    'success': True},
#   {'objectId': 153,
#    'uniqueId': 153,
#    'globalId': '9b3b7327-38c7-410c-88a2-713cff39609b',
#    'success': True},
#   {'objectId': 154,
#    'uniqueId': 154,
#    'globalId': 'f15da5ad-c698-48f1-b5e9-e901825a4358',
#    'success': True},
#   {'objectId': 155,
#    'uniqueId': 155,
#    'globalId': '4b323f71-539f-4dfb-8f47-72ff9fd9d439',
#    'success': True},
#   {'objectId': 156,
#    'uniqueId': 156,
#    'globalId': 'a77b7889-1277-4413-9708-e63a8f1c736b',
#    'success': True},
#   {'objectId': 157,
#    'uniqueId': 157,
#    'globalId': '8c1f284c-ea48-4c69-a35f-6c3f5983a108',
#    'success': True},
#   {'objectId': 251,
#    'uniqueId': 251,
#    'globalId': '568a6e9b-b051-4067-a83d-2658fb8cc4f5',
#    'success': True},
#   {'objectId': 158,
#    'uniqueId': 158,
#    'globalId': '1967b67f-7692-4a79-a4c8-cfa418b1f218',
#    'success': True},
#   {'objectId': 159,
#    'uniqueId': 159,
#    'globalId': '510d92fd-27e0-4303-add9-be9497f2a023',
#    'success': True},
#   {'objectId': 160,
#    'uniqueId': 160,
#    'globalId': '46154972-a34d-4022-b72c-7fe2c63b8a29',
#    'success': True},
#   {'objectId': 161,
#    'uniqueId': 161,
#    'globalId': '91605959-f145-44fe-87b0-71362c380d44',
#    'success': True},
#   {'objectId': 162,
#    'uniqueId': 162,
#    'globalId': '824f5960-440e-4385-a74f-83dfbed4526b',
#    'success': True},
#   {'objectId': 163,
#    'uniqueId': 163,
#    'globalId': '5416767a-1145-40f1-a814-22f12b3e2442',
#    'success': True},
#   {'objectId': 164,
#    'uniqueId': 164,
#    'globalId': 'a80f5b5c-e307-4940-8086-1a99f96a1c7c',
#    'success': True},
#   {'objectId': 165,
#    'uniqueId': 165,
#    'globalId': '8d8e8cf1-3664-4d5d-ba9c-5b4fb897fe67',
#    'success': True},
#   {'objectId': 166,
#    'uniqueId': 166,
#    'globalId': '1ac28a15-5d9c-45d9-9625-b80bbee863e7',
#    'success': True},
#   {'objectId': 167,
#    'uniqueId': 167,
#    'globalId': '83fd5a30-6c84-4560-8f79-444c1c21ad9c',
#    'success': True},
#   {'objectId': 168,
#    'uniqueId': 168,
#    'globalId': 'f468d4e7-def1-4758-ac1b-dcc8d24acb1b',
#    'success': True},
#   {'objectId': 169,
#    'uniqueId': 169,
#    'globalId': '80aa2cc3-2dba-474e-9112-947b1d24c434',
#    'success': True},
#   {'objectId': 170,
#    'uniqueId': 170,
#    'globalId': '3f257226-9268-43c0-834f-0b7627c73534',
#    'success': True},
#   {'objectId': 171,
#    'uniqueId': 171,
#    'globalId': 'eefb0ac1-3465-43ce-a285-99c52eb5c295',
#    'success': True},
#   {'objectId': 172,
#    'uniqueId': 172,
#    'globalId': '6e353e0b-8395-4720-ab43-8f34248fa7a9',
#    'success': True},
#   {'objectId': 173,
#    'uniqueId': 173,
#    'globalId': '843c688c-b55e-422a-bd50-8cd0b76d7335',
#    'success': True},
#   {'objectId': 174,
#    'uniqueId': 174,
#    'globalId': '54e31a3a-d41c-4a5d-95c2-3d7627d86cb3',
#    'success': True},
#   {'objectId': 175,
#    'uniqueId': 175,
#    'globalId': '48925f15-05d0-41e1-8f77-43e67bcce72b',
#    'success': True},
#   {'objectId': 176,
#    'uniqueId': 176,
#    'globalId': '40f18630-bd13-490b-bfdc-9937e3692d50',
#    'success': True},
#   {'objectId': 177,
#    'uniqueId': 177,
#    'globalId': '733ce270-a78d-4506-80e5-21c339af333d',
#    'success': True},
#   {'objectId': 178,
#    'uniqueId': 178,
#    'globalId': 'd1a0d809-851d-4842-b0e4-fbc438aa1a5a',
#    'success': True},
#   {'objectId': 179,
#    'uniqueId': 179,
#    'globalId': '3d47fbbc-a6a9-415c-bd35-36c71b4e6e14',
#    'success': True},
#   {'objectId': 180,
#    'uniqueId': 180,
#    'globalId': '2ad84ca4-823d-41dc-9c5b-b8e6dbdf06c5',
#    'success': True},
#   {'objectId': 181,
#    'uniqueId': 181,
#    'globalId': '21f61163-5e1e-4d43-a805-2e64049ffae7',
#    'success': True},
#   {'objectId': 182,
#    'uniqueId': 182,
#    'globalId': '373e9cb5-759c-420b-a680-494559750c2b',
#    'success': True},
#   {'objectId': 183,
#    'uniqueId': 183,
#    'globalId': '105c59d6-ac35-4756-ace3-a120d431cba4',
#    'success': True},
#   {'objectId': 184,
#    'uniqueId': 184,
#    'globalId': '7a0b3f2a-25da-4aac-8d88-cd4d1a67426c',
#    'success': True},
#   {'objectId': 185,
#    'uniqueId': 185,
#    'globalId': '746f0d91-41c0-483d-9eb9-3c300966de6a',
#    'success': True},
#   {'objectId': 186,
#    'uniqueId': 186,
#    'globalId': 'a396bed3-33b6-4cfd-ac6a-a85fed08e930',
#    'success': True},
#   {'objectId': 187,
#    'uniqueId': 187,
#    'globalId': '35c585c4-1f07-4690-8eed-c1b761b67f12',
#    'success': True},
#   {'objectId': 188,
#    'uniqueId': 188,
#    'globalId': '49a1364b-4820-4914-b20a-81210b6fa879',
#    'success': True},
#   {'objectId': 189,
#    'uniqueId': 189,
#    'globalId': 'e78fc84b-5e78-4016-97a7-3f6c39fc4c70',
#    'success': True},
#   {'objectId': 190,
#    'uniqueId': 190,
#    'globalId': '7ecd68c5-6c53-457a-88d0-eab02bfb67fd',
#    'success': True},
#   {'objectId': 191,
#    'uniqueId': 191,
#    'globalId': '451f809b-12f2-4c84-84a5-f30385750936',
#    'success': True},
#   {'objectId': 192,
#    'uniqueId': 192,
#    'globalId': '91fe3856-d434-497a-b34a-56ba18d3228b',
#    'success': True},
#   {'objectId': 193,
#    'uniqueId': 193,
#    'globalId': '310c3875-b803-4470-ae78-821a0f4e3495',
#    'success': True},
#   {'objectId': 194,
#    'uniqueId': 194,
#    'globalId': 'd084834f-cc93-4170-8963-f030a4ec2300',
#    'success': True},
#   {'objectId': 195,
#    'uniqueId': 195,
#    'globalId': '0916889d-f00a-4db1-b3fb-94e416b3c17d',
#    'success': True},
#   {'objectId': 196,
#    'uniqueId': 196,
#    'globalId': '27f5781c-8c56-4532-8d54-baee09c7254b',
#    'success': True},
#   {'objectId': 197,
#    'uniqueId': 197,
#    'globalId': '445d666a-9836-4775-8700-bd10ce82ac8c',
#    'success': True},
#   {'objectId': 198,
#    'uniqueId': 198,
#    'globalId': '79a4e2cc-a11b-4e1e-8a80-3212908fc3eb',
#    'success': True},
#   {'objectId': 199,
#    'uniqueId': 199,
#    'globalId': '9385d72e-2917-4e03-aba9-8c1869657506',
#    'success': True},
#   {'objectId': 200,
#    'uniqueId': 200,
#    'globalId': 'eac5543c-3661-4eec-b6d1-e3ed4ae5f332',
#    'success': True},
#   {'objectId': 201,
#    'uniqueId': 201,
#    'globalId': 'a9876c34-b478-4322-a56b-93d25af3d87c',
#    'success': True},
#   {'objectId': 202,
#    'uniqueId': 202,
#    'globalId': '82ae1d5d-fa67-444d-8422-8e38961dcfb1',
#    'success': True},
#   {'objectId': 203,
#    'uniqueId': 203,
#    'globalId': '02c6b892-f4c6-4728-b2a7-0a718b554d57',
#    'success': True},
#   {'objectId': 204,
#    'uniqueId': 204,
#    'globalId': 'c94b235a-3799-474e-80e5-9716c78f3f89',
#    'success': True},
#   {'objectId': 205,
#    'uniqueId': 205,
#    'globalId': 'd242e8e8-a756-469e-869b-705b5c52e0ba',
#    'success': True},
#   {'objectId': 206,
#    'uniqueId': 206,
#    'globalId': '5c0f7409-9040-44fb-9062-99384c42af8b',
#    'success': True},
#   {'objectId': 207,
#    'uniqueId': 207,
#    'globalId': 'f4d1825f-42f2-4786-a76b-51da56955fc1',
#    'success': True},
#   {'objectId': 208,
#    'uniqueId': 208,
#    'globalId': '9efb702f-f24e-46cc-bae3-adc61c8f08a8',
#    'success': True},
#   {'objectId': 209,
#    'uniqueId': 209,
#    'globalId': '263bef95-4866-4ca7-b0e2-b63d30d3fffb',
#    'success': True},
#   {'objectId': 210,
#    'uniqueId': 210,
#    'globalId': 'e95fbbd8-3769-4720-9092-55b2d293fc80',
#    'success': True},
#   {'objectId': 211,
#    'uniqueId': 211,
#    'globalId': '85ea185e-91ec-4cda-a02a-0a95889a82e5',
#    'success': True},
#   {'objectId': 212,
#    'uniqueId': 212,
#    'globalId': '00ff7bfa-8b9e-4daa-a4c5-7ddc49765b3c',
#    'success': True},
#   {'objectId': 213,
#    'uniqueId': 213,
#    'globalId': '216434f3-9e49-4f6e-ab53-a1398cbfaf34',
#    'success': True},
#   {'objectId': 214,
#    'uniqueId': 214,
#    'globalId': '20f92ed7-6ded-4237-8be2-8fcf712a0f84',
#    'success': True},
#   {'objectId': 215,
#    'uniqueId': 215,
#    'globalId': 'cc7edfa4-7581-4cd8-a614-e9ae410fed8c',
#    'success': True},
#   {'objectId': 216,
#    'uniqueId': 216,
#    'globalId': '3b68b83c-a7f9-4c52-b44e-0e11f1b055ab',
#    'success': True},
#   {'objectId': 217,
#    'uniqueId': 217,
#    'globalId': '7578f600-3f56-4bab-993f-d1fcedb9cbfc',
#    'success': True},
#   {'objectId': 218,
#    'uniqueId': 218,
#    'globalId': '9c985044-bdd6-4911-8d4f-e21769861f5d',
#    'success': True},
#   {'objectId': 219,
#    'uniqueId': 219,
#    'globalId': '49de4a11-9e56-4e34-98a6-2cce1e32882d',
#    'success': True},
#   {'objectId': 220,
#    'uniqueId': 220,
#    'globalId': '957493fc-571a-434b-b6f9-537e4191f006',
#    'success': True},
#   {'objectId': 221,
#    'uniqueId': 221,
#    'globalId': '2aefce56-f5c0-4c9f-91ff-cb0f29119d2e',
#    'success': True},
#   {'objectId': 222,
#    'uniqueId': 222,
#    'globalId': '190d0b55-9c6e-494c-a2f7-9d24eb931410',
#    'success': True},
#   {'objectId': 223,
#    'uniqueId': 223,
#    'globalId': '411054e4-8695-4ae8-93ad-800e3398f033',
#    'success': True},
#   {'objectId': 224,
#    'uniqueId': 224,
#    'globalId': 'ed31ca31-915a-4feb-a5a5-67d7cb043f6b',
#    'success': True},
#   {'objectId': 225,
#    'uniqueId': 225,
#    'globalId': '1b3c5156-3398-4923-9c79-280e9f9a2144',
#    'success': True},
#   {'objectId': 226,
#    'uniqueId': 226,
#    'globalId': '72760164-b15b-4352-8a2e-e6ee750c3075',
#    'success': True},
#   {'objectId': 227,
#    'uniqueId': 227,
#    'globalId': '245ea088-aef9-4dce-b3a3-d1a307e55938',
#    'success': True},
#   {'objectId': 228,
#    'uniqueId': 228,
#    'globalId': '0e37e37f-a96a-4ece-8489-58dcba87c14d',
#    'success': True},
#   {'objectId': 229,
#    'uniqueId': 229,
#    'globalId': '416fd4b0-cc79-4f4d-9373-62c221377980',
#    'success': True},
#   {'objectId': 230,
#    'uniqueId': 230,
#    'globalId': 'f61a3daa-c0f6-4ac3-9649-9c5cf26ff275',
#    'success': True},
#   {'objectId': 231,
#    'uniqueId': 231,
#    'globalId': 'fed33431-796f-4c4a-8150-09e9f3350d11',
#    'success': True},
#   {'objectId': 232,
#    'uniqueId': 232,
#    'globalId': '70c88468-58da-4c38-b498-b1ed2361e34e',
#    'success': True},
#   {'objectId': 233,
#    'uniqueId': 233,
#    'globalId': '75553998-346e-4c88-9da5-5acad86d8940',
#    'success': True},
#   {'objectId': 234,
#    'uniqueId': 234,
#    'globalId': 'a7272cc9-6155-4bd8-82c0-4b6cbf48eb21',
#    'success': True},
#   {'objectId': 235,
#    'uniqueId': 235,
#    'globalId': 'a9af02a2-35ef-4d2a-8f70-9e7507fc52d6',
#    'success': True},
#   {'objectId': 236,
#    'uniqueId': 236,
#    'globalId': '9d2e0f53-543e-4545-aa2d-e1dd155e3bd4',
#    'success': True},
#   {'objectId': 237,
#    'uniqueId': 237,
#    'globalId': '9d27d4c7-fecf-44ea-a1a8-eb9de1b885fa',
#    'success': True},
#   {'objectId': 238,
#    'uniqueId': 238,
#    'globalId': 'f73fc075-7a42-43dc-bde7-0782fa0c351e',
#    'success': True},
#   {'objectId': 239,
#    'uniqueId': 239,
#    'globalId': 'ca38face-4afd-42d2-8be9-e0800eea01d9',
#    'success': True},
#   {'objectId': 240,
#    'uniqueId': 240,
#    'globalId': 'b2d202bd-483c-4fe5-a774-0abe81e919a7',
#    'success': True},
#   {'objectId': 241,
#    'uniqueId': 241,
#    'globalId': 'b4ea9b2b-af2b-4637-83cb-55b845125e05',
#    'success': True},
#   {'objectId': 242,
#    'uniqueId': 242,
#    'globalId': 'b23599aa-7f33-4d5d-9bc6-c97d637b9872',
#    'success': True},
#   {'objectId': 243,
#    'uniqueId': 243,
#    'globalId': 'acd0f9f8-a24a-4d36-8ccf-bbde32ad0e2a',
#    'success': True},
#   {'objectId': 244,
#    'uniqueId': 244,
#    'globalId': '0f1175ba-620e-498f-9f60-d90b4fd8608b',
#    'success': True},
#   {'objectId': 245,
#    'uniqueId': 245,
#    'globalId': 'ffd015b3-5d51-4c7e-a3cf-e38973a489c6',
#    'success': True},
#   {'objectId': 252,
#    'uniqueId': 252,
#    'globalId': '400c1f3d-25cc-4f1f-be22-c43f410959d3',
#    'success': True},
#   {'objectId': 246,
#    'uniqueId': 246,
#    'globalId': 'b38ca183-713a-4e60-ab57-d12e2ff837d2',
#    'success': True},
#   {'objectId': 247,
#    'uniqueId': 247,
#    'globalId': '41abf2eb-b0d4-45dd-9c31-41d48afe2627',
#    'success': True},
#   {'objectId': 248,
#    'uniqueId': 248,
#    'globalId': '069af20d-e655-4d3c-b50b-cf9eb0fd8562',
#    'success': True},
#   {'objectId': 249,
#    'uniqueId': 249,
#    'globalId': 'bcfec08d-8546-4e26-acc6-400745dba434',
#    'success': True}],
#  'deleteResults': []}

# %% [markdown]
# # Adding new fields of information to National Report Cards centroid service

# %%
import arcgis
from arcgis.gis import GIS, GroupManager
from arcgis.features import FeatureLayerCollection
from arcgis.features import FeatureLayer
from copy import deepcopy
from arcgis import geometry
import re
from pprint import pprint
import pandas as pd

# %%
env_path = ".env"
with open(env_path) as f:
    env = {}
    for line in f:
        env_key, _val = line.split("=")
        env_value = _val.split("\n")[0]
        env[env_key] = env_value

# %%
aol_password = env['aol_key']
aol_username = env['aol_username']

# %%
gis = GIS("https://eowilson.maps.arcgis.com", aol_username, aol_password)

# %%
def create_strict_reg_exp(to_search):
    try:
        reg_exp = f"^{to_search}$"
        #logging.info(f"regular expression is: {reg_exp}")
    except:
        print("There was a problem with the string.")
    return reg_exp

# %%
def findItemGetID(csvName, gis):
    try:
        searched_item = gis.content.search(csvName, item_type = "Feature Layer")
        for i in searched_item:
            reg_exp = create_strict_reg_exp(csvName)
            if re.search(reg_exp, i.title)!= None:    
                #logging.info(f"{csvName} has the id: {i.id}")
                return i.id
    except:
        print("There was a problem finding the item")

# %% [markdown]
# ## Get item that has to be updated

# %%
item_id = findItemGetID("gadm_centroid", gis)

# %%
item = gis.content.get(item_id)

# %%
flayer = item.layers[0]

# %%
sdf = pd.DataFrame.spatial.from_layer(flayer)

# %%
type(sdf)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Process the csv with total number of species so it can have matching field with the service

# %%
n_by_taxa = pd.read_csv("data/Terrestrial_vertebrate_groups_by_country_20200617.csv")

# %%
n_by_taxa_wide = n_by_taxa.pivot_table(index=['iso3', 'countryname'], columns='speciesgroup', values='nspecies')

# %%
n_by_taxa_wide['nspecies'] = n_by_taxa_wide.sum(axis = 1)

# %%
n_by_taxa_wide.index.name = 'iso3'
n_by_taxa_wide.reset_index(inplace=True)

# %%
n_by_taxa_wide = n_by_taxa_wide.fillna(0)

# %%
n_by_taxa_wide.head()
# Out:
# speciesgroup iso3  countryname  amphibians  birds  mammals  reptiles  nspecies
# 0             ABW        Aruba         3.0   92.0      4.0      32.0     131.0
# 1             AFG  Afghanistan         9.0  371.0    139.0     145.0     664.0
# 2             AGO       Angola       128.0  917.0    299.0     336.0    1680.0
# 3             AIA     Anguilla         2.0  106.0      5.0      12.0     125.0
# 4             ALA        Åland         5.0  112.0     11.0       4.0     132.0

# %%
n_by_taxa_wide.shape
# Out:
# (255, 7)

# %% [markdown]
# ## Prepare the service to have more fields with the total number of species

# %%
#Get the existing list of fields on the published feature layer
flayer_fields = flayer.manager.properties.fields

# %%
for field in flayer_fields:
    print(f"{field.name:13}|  {field.alias:13}|  {field.type:25}|  {field.sqlType}")
# Out:
# OBJECTID_1   |  OBJECTID_1   |  esriFieldTypeOID         |  sqlTypeOther
# GID_0        |  GID_0        |  esriFieldTypeString      |  sqlTypeOther
# NAME_0       |  NAME_0       |  esriFieldTypeString      |  sqlTypeOther
# jpg_url      |  jpg_url      |  esriFieldTypeString      |  sqlTypeOther
# OBJECTID     |  OBJECTID     |  esriFieldTypeInteger     |  sqlTypeOther
# GID          |  GID          |  esriFieldTypeString      |  sqlTypeOther
# Area         |  Area         |  esriFieldTypeInteger     |  sqlTypeOther
# GNI_PPP      |  GNI_PPP      |  esriFieldTypeDouble      |  sqlTypeOther
# Protected    |  Protected    |  esriFieldTypeInteger     |  sqlTypeOther
# HM_0         |  HM_0         |  esriFieldTypeInteger     |  sqlTypeOther
# HM_low       |  HM_low       |  esriFieldTypeInteger     |  sqlTypeOther
# HM_moderate  |  HM_moderate  |  esriFieldTypeInteger     |  sqlTypeOther
# HM_high      |  HM_high      |  esriFieldTypeInteger     |  sqlTypeOther
# Population2016|  SUM          |  esriFieldTypeDouble      |  sqlTypeOther
# max_amph     |  max_amph     |  esriFieldTypeInteger     |  sqlTypeOther
# max_bird     |  max_bird     |  esriFieldTypeInteger     |  sqlTypeOther
# max_mamm     |  max_mamm     |  esriFieldTypeInteger     |  sqlTypeOther
# max_rept     |  max_rept     |  esriFieldTypeInteger     |  sqlTypeOther
# max_cact     |  max_cact     |  esriFieldTypeInteger     |  sqlTypeOther
# max_coni     |  max_coni     |  esriFieldTypeInteger     |  sqlTypeOther
# max_all      |  max_all      |  esriFieldTypeInteger     |  sqlTypeOther
# sentence     |  sentence     |  esriFieldTypeString      |  sqlTypeOther
# prop_protected|  prop_protected|  esriFieldTypeDouble      |  sqlTypeOther
# gadm_prop_COUNT|  COUNT        |  esriFieldTypeInteger     |  sqlTypeOther
# N_SPECIES    |  N_SPECIES    |  esriFieldTypeInteger     |  sqlTypeOther
# SPI          |  SPI          |  esriFieldTypeDouble      |  sqlTypeOther
# amphibians   |  amphibians   |  esriFieldTypeInteger     |  sqlTypeOther
# birds        |  birds        |  esriFieldTypeInteger     |  sqlTypeOther
# mammals      |  mammals      |  esriFieldTypeInteger     |  sqlTypeOther
# nspecies     |  nspecies     |  esriFieldTypeInteger     |  sqlTypeOther
# reptiles     |  reptiles     |  esriFieldTypeInteger     |  sqlTypeOther
# total_endemic|  total_endemic|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_amphibians|  endemic_amphibians|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_birds|  endemic_birds|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_mammals|  endemic_mammals|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_reptiles|  endemic_reptiles|  esriFieldTypeInteger     |  sqlTypeOther
# protection_needed|  protection_needed|  esriFieldTypeDouble      |  sqlTypeOther
# spi_mean     |  Average SPI  |  esriFieldTypeDouble      |  sqlTypeOther

# %%
# get a template field with the type of interest in this case esriFieldTypeInteger
template_field = dict(deepcopy(flayer_fields[6]))
template_field
# Out:
# {'name': 'Area',
#  'type': 'esriFieldTypeInteger',
#  'alias': 'Area',
#  'sqlType': 'sqlTypeOther',
#  'nullable': True,
#  'editable': True,
#  'visible': True,
#  'domain': None,
#  'defaultValue': None}

# %%
# get the list of new fields to add from the third spreadsheet, that are not in spread sheets 1,2
new_field_names = list(n_by_taxa_wide.columns.difference(sdf.columns))
new_field_names
# when doing this there are two fields iso3 and country that are kept and they are not needed as the join of the tables is done feature by feature
# Out:
# ['countryname', 'iso3']

# %%
new_field_names = ['amphibians', 'birds', 'mammals', 'nspecies', 'reptiles']
new_field_names

# %%
fields_to_be_added = []
for new_field_name in new_field_names:
    current_field = deepcopy(template_field)
    if new_field_name.lower() == 'class':
        current_field['sqlType'] = 'sqlTypeVarchar'
        current_field['type'] = 'esriFieldTypeInteger'
        #current_field['length'] = 8000
    current_field['name'] = new_field_name.lower()
    current_field['alias'] = new_field_name
    fields_to_be_added.append(current_field)
    
len(fields_to_be_added)
# Out:
# 5

# %%
flayer.manager.add_to_definition({'fields':fields_to_be_added})
# Out:
# {'success': True}

# %%
new_fields = flayer.manager.properties.fields
len(new_fields)
# Out:
# 31

# %%
for field in new_fields:
    print(f"{field.name:10}|  {field.type}")
# Out:
# OBJECTID_1|  esriFieldTypeOID
# GID_0     |  esriFieldTypeString
# NAME_0    |  esriFieldTypeString
# jpg_url   |  esriFieldTypeString
# OBJECTID  |  esriFieldTypeInteger
# GID       |  esriFieldTypeString
# Area      |  esriFieldTypeInteger
# GNI_PPP   |  esriFieldTypeDouble
# Protected |  esriFieldTypeInteger
# HM_0      |  esriFieldTypeInteger
# HM_low    |  esriFieldTypeInteger
# HM_moderate|  esriFieldTypeInteger
# HM_high   |  esriFieldTypeInteger
# Population2016|  esriFieldTypeDouble
# max_amph  |  esriFieldTypeInteger
# max_bird  |  esriFieldTypeInteger
# max_mamm  |  esriFieldTypeInteger
# max_rept  |  esriFieldTypeInteger
# max_cact  |  esriFieldTypeInteger
# max_coni  |  esriFieldTypeInteger
# max_all   |  esriFieldTypeInteger
# sentence  |  esriFieldTypeString
# prop_protected|  esriFieldTypeDouble
# gadm_prop_COUNT|  esriFieldTypeInteger
# N_SPECIES |  esriFieldTypeInteger
# SPI       |  esriFieldTypeDouble
# amphibians|  esriFieldTypeInteger
# birds     |  esriFieldTypeInteger
# mammals   |  esriFieldTypeInteger
# nspecies  |  esriFieldTypeInteger
# reptiles  |  esriFieldTypeInteger

# %% [markdown]
# ## Update the data in the new fields with the data from the csv of total number of species

# %%
fset2 = flayer.query()
features2 = fset2.features

# %%
features_for_update = []
for country_id in n_by_taxa_wide['iso3']:
    try:
        # get the matching row from csv
        matching_row = n_by_taxa_wide.where(n_by_taxa_wide.iso3 == country_id).dropna()

        print(str(country_id) + " Adding additional attributes for: " + matching_row['iso3'].values[0])

        # get the feature to be updated
        assert  len([f for f in features2 if f.attributes['GID_0'] == country_id]),  "country not matched"
        original_feature = [f for f in features2 if f.attributes['GID_0'] == country_id][0]
        feature_to_be_updated = deepcopy(original_feature)

        # assign the updated values
        feature_to_be_updated.attributes['amphibians'] = matching_row['amphibians'].values[0]
        feature_to_be_updated.attributes['birds'] = int(matching_row['birds'])
        #feature_to_be_updated.attributes['countryname'] = str(matching_row['countryname'])
        feature_to_be_updated.attributes['mammals'] = int(matching_row['mammals'])
        #feature_to_be_updated.attributes['iso3'] = str(matching_row['iso3'])
        feature_to_be_updated.attributes['nspecies'] = int(matching_row['nspecies'])
        feature_to_be_updated.attributes['reptiles'] = int(matching_row['reptiles'])

        #add this to the list of features to be updated
        features_for_update.append(feature_to_be_updated)
        #print(str(country_id) + " Done additional attributes for: " + matching_row['countryname'].values[0])
    except:
        print(f"{country_id} not available in service")
# Out:
# ABW Adding additional attributes for: ABW
# AFG Adding additional attributes for: AFG
# AGO Adding additional attributes for: AGO
# AIA Adding additional attributes for: AIA
# ALA Adding additional attributes for: ALA
# ALB Adding additional attributes for: ALB
# AND Adding additional attributes for: AND
# ARE Adding additional attributes for: ARE
# ARG Adding additional attributes for: ARG
# ARM Adding additional attributes for: ARM
# ASM Adding additional attributes for: ASM
# ATA Adding additional attributes for: ATA
# ATF Adding additional attributes for: ATF
# ATG Adding additional attributes for: ATG
# AUS Adding additional attributes for: AUS
# AUT Adding additional attributes for: AUT
# AZE Adding additional attributes for: AZE
# BDI Adding additional attributes for: BDI
# BEL Adding additional attributes for: BEL
# BEN Adding additional attributes for: BEN
# BES Adding additional attributes for: BES
# BFA Adding additional attributes for: BFA
# BGD Adding additional attributes for: BGD
# BGR Adding additional attributes for: BGR
# BHR Adding additional attributes for: BHR
# BHS Adding additional attributes for: BHS
# BIH Adding additional attributes for: BIH
# BLM Adding additional attributes for: BLM
# BLR Adding additional attributes for: BLR
# BLZ Adding additional attributes for: BLZ
# BMU Adding additional attributes for: BMU
# BOL Adding additional attributes for: BOL
# BRA Adding additional attributes for: BRA
# BRB Adding additional attributes for: BRB
# BRN Adding additional attributes for: BRN
# BTN Adding additional attributes for: BTN
# BVT Adding additional attributes for: BVT
# BWA Adding additional attributes for: BWA
# CAF Adding additional attributes for: CAF
# CAN Adding additional attributes for: CAN
# CCK Adding additional attributes for: CCK
# CHE Adding additional attributes for: CHE
# CHL Adding additional attributes for: CHL
# CHN Adding additional attributes for: CHN
# CIV Adding additional attributes for: CIV
# CMR Adding additional attributes for: CMR
# COD Adding additional attributes for: COD
# COG Adding additional attributes for: COG
# COK Adding additional attributes for: COK
# COL Adding additional attributes for: COL
# COM Adding additional attributes for: COM
# CPV Adding additional attributes for: CPV
# CRI Adding additional attributes for: CRI
# CUB Adding additional attributes for: CUB
# CUW Adding additional attributes for: CUW
# CXR Adding additional attributes for: CXR
# CYM Adding additional attributes for: CYM
# CYP Adding additional attributes for: CYP
# CZE Adding additional attributes for: CZE
# DEU Adding additional attributes for: DEU
# DJI Adding additional attributes for: DJI
# DMA Adding additional attributes for: DMA
# DNK Adding additional attributes for: DNK
# DOM Adding additional attributes for: DOM
# DZA Adding additional attributes for: DZA
# ECU Adding additional attributes for: ECU
# EGY Adding additional attributes for: EGY
# ERI Adding additional attributes for: ERI
# ESH Adding additional attributes for: ESH
# ESP Adding additional attributes for: ESP
# EST Adding additional attributes for: EST
# ETH Adding additional attributes for: ETH
# FIN Adding additional attributes for: FIN
# FJI Adding additional attributes for: FJI
# FLK Adding additional attributes for: FLK
# FRA Adding additional attributes for: FRA
# FRO Adding additional attributes for: FRO
# FSM Adding additional attributes for: FSM
# GAB Adding additional attributes for: GAB
# GBR Adding additional attributes for: GBR
# GEO Adding additional attributes for: GEO
# GGY Adding additional attributes for: GGY
# GHA Adding additional attributes for: GHA
# GIB Adding additional attributes for: GIB
# GIN Adding additional attributes for: GIN
# GLP Adding additional attributes for: GLP
# GMB Adding additional attributes for: GMB
# GNB Adding additional attributes for: GNB
# GNQ Adding additional attributes for: GNQ
# GRC Adding additional attributes for: GRC
# GRD Adding additional attributes for: GRD
# GRL Adding additional attributes for: GRL
# GTM Adding additional attributes for: GTM
# GUF Adding additional attributes for: GUF
# GUM Adding additional attributes for: GUM
# GUY Adding additional attributes for: GUY
# HKG Adding additional attributes for: HKG
# HMD Adding additional attributes for: HMD
# HND Adding additional attributes for: HND
# HRV Adding additional attributes for: HRV
# HTI Adding additional attributes for: HTI
# HUN Adding additional attributes for: HUN
# IDN Adding additional attributes for: IDN
# IMN Adding additional attributes for: IMN
# IND Adding additional attributes for: IND
# IOT Adding additional attributes for: IOT
# IOT not available in service
# IRL Adding additional attributes for: IRL
# IRN Adding additional attributes for: IRN
# IRQ Adding additional attributes for: IRQ
# ISL Adding additional attributes for: ISL
# ISR Adding additional attributes for: ISR
# ITA Adding additional attributes for: ITA
# JAM Adding additional attributes for: JAM
# JEY Adding additional attributes for: JEY
# JOR Adding additional attributes for: JOR
# JPN Adding additional attributes for: JPN
# KAZ Adding additional attributes for: KAZ
# KEN Adding additional attributes for: KEN
# KGZ Adding additional attributes for: KGZ
# KHM Adding additional attributes for: KHM
# KIR Adding additional attributes for: KIR
# KNA Adding additional attributes for: KNA
# KOR Adding additional attributes for: KOR
# KWT Adding additional attributes for: KWT
# LAO Adding additional attributes for: LAO
# LBN Adding additional attributes for: LBN
# LBR Adding additional attributes for: LBR
# LBY Adding additional attributes for: LBY
# LCA Adding additional attributes for: LCA
# LIE Adding additional attributes for: LIE
# LKA Adding additional attributes for: LKA
# LSO Adding additional attributes for: LSO
# LTU Adding additional attributes for: LTU
# LUX Adding additional attributes for: LUX
# LVA Adding additional attributes for: LVA
# MAC Adding additional attributes for: MAC
# MAF Adding additional attributes for: MAF
# MAR Adding additional attributes for: MAR
# MCO Adding additional attributes for: MCO
# MDA Adding additional attributes for: MDA
# MDG Adding additional attributes for: MDG
# MDV Adding additional attributes for: MDV
# MEX Adding additional attributes for: MEX
# MHL Adding additional attributes for: MHL
# MKD Adding additional attributes for: MKD
# MLI Adding additional attributes for: MLI
# MLT Adding additional attributes for: MLT
# MMR Adding additional attributes for: MMR
# MNE Adding additional attributes for: MNE
# MNG Adding additional attributes for: MNG
# MNP Adding additional attributes for: MNP
# MOZ Adding additional attributes for: MOZ
# MRT Adding additional attributes for: MRT
# MSR Adding additional attributes for: MSR
# MTQ Adding additional attributes for: MTQ
# MUS Adding additional attributes for: MUS
# MWI Adding additional attributes for: MWI
# MYS Adding additional attributes for: MYS
# MYT Adding additional attributes for: MYT
# NAM Adding additional attributes for: NAM
# NCL Adding additional attributes for: NCL
# NER Adding additional attributes for: NER
# NFK Adding additional attributes for: NFK
# NGA Adding additional attributes for: NGA
# NIC Adding additional attributes for: NIC
# NIU Adding additional attributes for: NIU
# NLD Adding additional attributes for: NLD
# NOR Adding additional attributes for: NOR
# NPL Adding additional attributes for: NPL
# NRU Adding additional attributes for: NRU
# NZL Adding additional attributes for: NZL
# OMN Adding additional attributes for: OMN
# PAK Adding additional attributes for: PAK
# PAN Adding additional attributes for: PAN
# PCN Adding additional attributes for: PCN
# PER Adding additional attributes for: PER
# PHL Adding additional attributes for: PHL
# PLW Adding additional attributes for: PLW
# PNG Adding additional attributes for: PNG
# POL Adding additional attributes for: POL
# PRI Adding additional attributes for: PRI
# PRK Adding additional attributes for: PRK
# PRT Adding additional attributes for: PRT
# PRY Adding additional attributes for: PRY
# PSE Adding additional attributes for: PSE
# PYF Adding additional attributes for: PYF
# QAT Adding additional attributes for: QAT
# REU Adding additional attributes for: REU
# ROU Adding additional attributes for: ROU
# RUS Adding additional attributes for: RUS
# RWA Adding additional attributes for: RWA
# SAU Adding additional attributes for: SAU
# SDN Adding additional attributes for: SDN
# SEN Adding additional attributes for: SEN
# SGP Adding additional attributes for: SGP
# SGS Adding additional attributes for: SGS
# SHN Adding additional attributes for: SHN
# SJM Adding additional attributes for: SJM
# SLB Adding additional attributes for: SLB
# SLE Adding additional attributes for: SLE
# SLV Adding additional attributes for: SLV
# SMR Adding additional attributes for: SMR
# SOM Adding additional attributes for: SOM
# SPM Adding additional attributes for: SPM
# SRB Adding additional attributes for: SRB
# SSD Adding additional attributes for: SSD
# STP Adding additional attributes for: STP
# SUR Adding additional attributes for: SUR
# SVK Adding additional attributes for: SVK
# SVN Adding additional attributes for: SVN
# SWE Adding additional attributes for: SWE
# SWZ Adding additional attributes for: SWZ
# SXM Adding additional attributes for: SXM
# SYC Adding additional attributes for: SYC
# SYR Adding additional attributes for: SYR
# TCA Adding additional attributes for: TCA
# TCD Adding additional attributes for: TCD
# TGO Adding additional attributes for: TGO
# THA Adding additional attributes for: THA
# TJK Adding additional attributes for: TJK
# TKL Adding additional attributes for: TKL
# TKM Adding additional attributes for: TKM
# TLS Adding additional attributes for: TLS
# TON Adding additional attributes for: TON
# TTO Adding additional attributes for: TTO
# TUN Adding additional attributes for: TUN
# TUR Adding additional attributes for: TUR
# TUV Adding additional attributes for: TUV
# TWN Adding additional attributes for: TWN
# TZA Adding additional attributes for: TZA
# UGA Adding additional attributes for: UGA
# UKR Adding additional attributes for: UKR
# UMI Adding additional attributes for: UMI
# UMI not available in service
# URY Adding additional attributes for: URY
# USA Adding additional attributes for: USA
# UZB Adding additional attributes for: UZB
# VCT Adding additional attributes for: VCT
# VEN Adding additional attributes for: VEN
# VGB Adding additional attributes for: VGB
# VIR Adding additional attributes for: VIR
# VNM Adding additional attributes for: VNM
# VUT Adding additional attributes for: VUT
# WLF Adding additional attributes for: WLF
# WSM Adding additional attributes for: WSM
# XAD Adding additional attributes for: XAD
# XCA Adding additional attributes for: XCA
# XCA not available in service
# XCL Adding additional attributes for: XCL
# XKO Adding additional attributes for: XKO
# XNC Adding additional attributes for: XNC
# XPI Adding additional attributes for: XPI
# XSP Adding additional attributes for: XSP
#   {'objectId': 242, 'uniqueId': 242, 'globalId': None, 'success': True},
#   {'objectId': 243, 'uniqueId': 243, 'globalId': None, 'success': True},
#   {'objectId': 244, 'uniqueId': 244, 'globalId': None, 'success': True},
#   {'objectId': 245, 'uniqueId': 245, 'globalId': None, 'success': True},
#   {'objectId': 252, 'uniqueId': 252, 'globalId': None, 'success': True},
#   {'objectId': 246, 'uniqueId': 246, 'globalId': None, 'success': True},
#   {'objectId': 247, 'uniqueId': 247, 'globalId': None, 'success': True},
#   {'objectId': 248, 'uniqueId': 248, 'globalId': None, 'success': True},
#   {'objectId': 249, 'uniqueId': 249, 'globalId': None, 'success': True}],
#  'deleteResults': []}

# %% [markdown]
# # Preparing csv with number of endemic species

# %%
end_by_taxa = pd.read_csv("/Users/gretacvega/Documents/GitHub/he-scratchfolder/data/Terrestrial_vertebrate_totals_by_country_20200617_and_endemic_groups.csv")

# %%
end_by_taxa.head()
# Out:
#              countryname iso3  nspecies  total_endemic  endemic_amphibians  \
# 0            Afghanistan  AFG       664              5                   1
# 1  Akrotiri and Dhekelia  XAD       163              0                   0
# 2                  Åland  ALA       132              0                   0
# 3                Albania  ALB       398              0                   0
# 4                Algeria  DZA       516              4                   1
#
#    endemic_birds  endemic_mammals  endemic_reptiles
# 0              0                0                 4
# 1              0                0                 0
# 2              0                0                 0
# 3              0                0                 0
# 4              1                1                 1

# %%
end_by_taxa.shape
# Out:
# (255, 8)

# %%
flayer_fields = flayer.manager.properties.fields

# %%
for field in flayer_fields:
    print(f"{field.name:13}|  {field.alias:13}|  {field.type:25}|  {field.sqlType}")
# Out:
# OBJECTID_1   |  OBJECTID_1   |  esriFieldTypeOID         |  sqlTypeOther
# GID_0        |  GID_0        |  esriFieldTypeString      |  sqlTypeOther
# NAME_0       |  NAME_0       |  esriFieldTypeString      |  sqlTypeOther
# jpg_url      |  jpg_url      |  esriFieldTypeString      |  sqlTypeOther
# OBJECTID     |  OBJECTID     |  esriFieldTypeInteger     |  sqlTypeOther
# GID          |  GID          |  esriFieldTypeString      |  sqlTypeOther
# Area         |  Area         |  esriFieldTypeInteger     |  sqlTypeOther
# GNI_PPP      |  GNI_PPP      |  esriFieldTypeDouble      |  sqlTypeOther
# Protected    |  Protected    |  esriFieldTypeInteger     |  sqlTypeOther
# HM_0         |  HM_0         |  esriFieldTypeInteger     |  sqlTypeOther
# HM_low       |  HM_low       |  esriFieldTypeInteger     |  sqlTypeOther
# HM_moderate  |  HM_moderate  |  esriFieldTypeInteger     |  sqlTypeOther
# HM_high      |  HM_high      |  esriFieldTypeInteger     |  sqlTypeOther
# Population2016|  SUM          |  esriFieldTypeDouble      |  sqlTypeOther
# max_amph     |  max_amph     |  esriFieldTypeInteger     |  sqlTypeOther
# max_bird     |  max_bird     |  esriFieldTypeInteger     |  sqlTypeOther
# max_mamm     |  max_mamm     |  esriFieldTypeInteger     |  sqlTypeOther
# max_rept     |  max_rept     |  esriFieldTypeInteger     |  sqlTypeOther
# max_cact     |  max_cact     |  esriFieldTypeInteger     |  sqlTypeOther
# max_coni     |  max_coni     |  esriFieldTypeInteger     |  sqlTypeOther
# max_all      |  max_all      |  esriFieldTypeInteger     |  sqlTypeOther
# sentence     |  sentence     |  esriFieldTypeString      |  sqlTypeOther
# prop_protected|  prop_protected|  esriFieldTypeDouble      |  sqlTypeOther
# gadm_prop_COUNT|  COUNT        |  esriFieldTypeInteger     |  sqlTypeOther
# N_SPECIES    |  N_SPECIES    |  esriFieldTypeInteger     |  sqlTypeOther
# SPI          |  SPI          |  esriFieldTypeDouble      |  sqlTypeOther
# amphibians   |  amphibians   |  esriFieldTypeInteger     |  sqlTypeOther
# birds        |  birds        |  esriFieldTypeInteger     |  sqlTypeOther
# mammals      |  mammals      |  esriFieldTypeInteger     |  sqlTypeOther
# nspecies     |  nspecies     |  esriFieldTypeInteger     |  sqlTypeOther
# reptiles     |  reptiles     |  esriFieldTypeInteger     |  sqlTypeOther

# %%
template_field = dict(deepcopy(flayer_fields[6]))
template_field
# Out:
# {'name': 'Area',
#  'type': 'esriFieldTypeInteger',
#  'alias': 'Area',
#  'sqlType': 'sqlTypeOther',
#  'nullable': True,
#  'editable': True,
#  'visible': True,
#  'domain': None,
#  'defaultValue': None}

# %%
new_field_names = ['total_endemic',	'endemic_amphibians',	'endemic_birds',	'endemic_mammals',	'endemic_reptiles']
new_field_names
# Out:
# ['total_endemic',
#  'endemic_amphibians',
#  'endemic_birds',
#  'endemic_mammals',
#  'endemic_reptiles']

# %%
fields_to_be_added = []
for new_field_name in new_field_names:
    current_field = deepcopy(template_field)
    if new_field_name.lower() == 'class':
        current_field['sqlType'] = 'sqlTypeVarchar'
        current_field['type'] = 'esriFieldTypeInteger'
        #current_field['length'] = 8000
    current_field['name'] = new_field_name.lower()
    current_field['alias'] = new_field_name
    fields_to_be_added.append(current_field)
    
len(fields_to_be_added)
# Out:
# 5

# %%
flayer.manager.add_to_definition({'fields':fields_to_be_added})
# Out:
# {'success': True}

# %%
new_fields = flayer.manager.properties.fields
len(new_fields)
# Out:
# 36

# %%
for field in new_fields:
    print(f"{field.name:10}|  {field.type}")
# Out:
# OBJECTID_1|  esriFieldTypeOID
# GID_0     |  esriFieldTypeString
# NAME_0    |  esriFieldTypeString
# jpg_url   |  esriFieldTypeString
# OBJECTID  |  esriFieldTypeInteger
# GID       |  esriFieldTypeString
# Area      |  esriFieldTypeInteger
# GNI_PPP   |  esriFieldTypeDouble
# Protected |  esriFieldTypeInteger
# HM_0      |  esriFieldTypeInteger
# HM_low    |  esriFieldTypeInteger
# HM_moderate|  esriFieldTypeInteger
# HM_high   |  esriFieldTypeInteger
# Population2016|  esriFieldTypeDouble
# max_amph  |  esriFieldTypeInteger
# max_bird  |  esriFieldTypeInteger
# max_mamm  |  esriFieldTypeInteger
# max_rept  |  esriFieldTypeInteger
# max_cact  |  esriFieldTypeInteger
# max_coni  |  esriFieldTypeInteger
# max_all   |  esriFieldTypeInteger
# sentence  |  esriFieldTypeString
# prop_protected|  esriFieldTypeDouble
# gadm_prop_COUNT|  esriFieldTypeInteger
# N_SPECIES |  esriFieldTypeInteger
# SPI       |  esriFieldTypeDouble
# amphibians|  esriFieldTypeInteger
# birds     |  esriFieldTypeInteger
# mammals   |  esriFieldTypeInteger
# nspecies  |  esriFieldTypeInteger
# reptiles  |  esriFieldTypeInteger
# total_endemic|  esriFieldTypeInteger
# endemic_amphibians|  esriFieldTypeInteger
# endemic_birds|  esriFieldTypeInteger
# endemic_mammals|  esriFieldTypeInteger
# endemic_reptiles|  esriFieldTypeInteger

# %% [markdown]
# # Update the data in the new fields with the data from the csv of total number of endemic species

# %%
fset2 = flayer.query()
features2 = fset2.features

# %%
features_for_update = []
for country_id in end_by_taxa['iso3']:
    try:
        # get the matching row from csv
        matching_row = end_by_taxa.where(end_by_taxa.iso3 == country_id).dropna()

        print(str(country_id) + " Adding additional attributes for: " + matching_row['iso3'].values[0])

        # get the feature to be updated
        assert  len([f for f in features2 if f.attributes['GID_0'] == country_id]),  "country not matched"
        original_feature = [f for f in features2 if f.attributes['GID_0'] == country_id][0]
        feature_to_be_updated = deepcopy(original_feature)

        # assign the updated values
        feature_to_be_updated.attributes['total_endemic'] = int(matching_row['total_endemic'])
        feature_to_be_updated.attributes['endemic_amphibians'] = int(matching_row['endemic_amphibians'])
        #feature_to_be_updated.attributes['countryname'] = str(matching_row['countryname'])
        feature_to_be_updated.attributes['endemic_birds'] = int(matching_row['endemic_birds'])
        #feature_to_be_updated.attributes['iso3'] = str(matching_row['iso3'])
        feature_to_be_updated.attributes['endemic_mammals'] = int(matching_row['endemic_mammals'])
        feature_to_be_updated.attributes['endemic_reptiles'] = int(matching_row['endemic_reptiles'])

        #add this to the list of features to be updated
        features_for_update.append(feature_to_be_updated)
        #print(str(country_id) + " Done additional attributes for: " + matching_row['countryname'].values[0])
    except:
        print(f"{country_id} not available in service")
# Out:
# AFG Adding additional attributes for: AFG
# XAD Adding additional attributes for: XAD
# ALA Adding additional attributes for: ALA
# ALB Adding additional attributes for: ALB
# DZA Adding additional attributes for: DZA
# ASM Adding additional attributes for: ASM
# AND Adding additional attributes for: AND
# AGO Adding additional attributes for: AGO
# AIA Adding additional attributes for: AIA
# ATA Adding additional attributes for: ATA
# ATG Adding additional attributes for: ATG
# ARG Adding additional attributes for: ARG
# ARM Adding additional attributes for: ARM
# ABW Adding additional attributes for: ABW
# AUS Adding additional attributes for: AUS
# AUT Adding additional attributes for: AUT
# AZE Adding additional attributes for: AZE
# BHS Adding additional attributes for: BHS
# BHR Adding additional attributes for: BHR
# BGD Adding additional attributes for: BGD
# BRB Adding additional attributes for: BRB
# BLR Adding additional attributes for: BLR
# BEL Adding additional attributes for: BEL
# BLZ Adding additional attributes for: BLZ
# BEN Adding additional attributes for: BEN
# BMU Adding additional attributes for: BMU
# BTN Adding additional attributes for: BTN
# BOL Adding additional attributes for: BOL
# BES Adding additional attributes for: BES
# BIH Adding additional attributes for: BIH
# BWA Adding additional attributes for: BWA
# BVT Adding additional attributes for: BVT
# BRA Adding additional attributes for: BRA
# IOT Adding additional attributes for: IOT
# IOT not available in service
# VGB Adding additional attributes for: VGB
# BRN Adding additional attributes for: BRN
# BGR Adding additional attributes for: BGR
# BFA Adding additional attributes for: BFA
# BDI Adding additional attributes for: BDI
# KHM Adding additional attributes for: KHM
# CMR Adding additional attributes for: CMR
# CAN Adding additional attributes for: CAN
# CPV Adding additional attributes for: CPV
# XCA Adding additional attributes for: XCA
# XCA not available in service
# CYM Adding additional attributes for: CYM
# CAF Adding additional attributes for: CAF
# TCD Adding additional attributes for: TCD
# CHL Adding additional attributes for: CHL
# CHN Adding additional attributes for: CHN
# CXR Adding additional attributes for: CXR
# XCL Adding additional attributes for: XCL
# CCK Adding additional attributes for: CCK
# COL Adding additional attributes for: COL
# COM Adding additional attributes for: COM
# COK Adding additional attributes for: COK
# CRI Adding additional attributes for: CRI
# CIV Adding additional attributes for: CIV
# HRV Adding additional attributes for: HRV
# CUB Adding additional attributes for: CUB
# CUW Adding additional attributes for: CUW
# CYP Adding additional attributes for: CYP
# CZE Adding additional attributes for: CZE
# COD Adding additional attributes for: COD
# DNK Adding additional attributes for: DNK
# DJI Adding additional attributes for: DJI
# DMA Adding additional attributes for: DMA
# DOM Adding additional attributes for: DOM
# ECU Adding additional attributes for: ECU
# EGY Adding additional attributes for: EGY
# SLV Adding additional attributes for: SLV
# GNQ Adding additional attributes for: GNQ
# ERI Adding additional attributes for: ERI
# EST Adding additional attributes for: EST
# ETH Adding additional attributes for: ETH
# FLK Adding additional attributes for: FLK
# FRO Adding additional attributes for: FRO
# FJI Adding additional attributes for: FJI
# FIN Adding additional attributes for: FIN
# FRA Adding additional attributes for: FRA
# GUF Adding additional attributes for: GUF
# PYF Adding additional attributes for: PYF
# ATF Adding additional attributes for: ATF
# GAB Adding additional attributes for: GAB
# GMB Adding additional attributes for: GMB
# GEO Adding additional attributes for: GEO
# DEU Adding additional attributes for: DEU
# GHA Adding additional attributes for: GHA
# GIB Adding additional attributes for: GIB
# GRC Adding additional attributes for: GRC
# GRL Adding additional attributes for: GRL
# GRD Adding additional attributes for: GRD
# GLP Adding additional attributes for: GLP
# GUM Adding additional attributes for: GUM
# GTM Adding additional attributes for: GTM
# GGY Adding additional attributes for: GGY
# GIN Adding additional attributes for: GIN
# GNB Adding additional attributes for: GNB
# GUY Adding additional attributes for: GUY
# HTI Adding additional attributes for: HTI
# HMD Adding additional attributes for: HMD
# HND Adding additional attributes for: HND
# HKG Adding additional attributes for: HKG
# HUN Adding additional attributes for: HUN
# ISL Adding additional attributes for: ISL
# IND Adding additional attributes for: IND
# IDN Adding additional attributes for: IDN
# IRN Adding additional attributes for: IRN
# IRQ Adding additional attributes for: IRQ
# IRL Adding additional attributes for: IRL
# IMN Adding additional attributes for: IMN
# ISR Adding additional attributes for: ISR
# ITA Adding additional attributes for: ITA
# JAM Adding additional attributes for: JAM
# JPN Adding additional attributes for: JPN
# JEY Adding additional attributes for: JEY
# JOR Adding additional attributes for: JOR
# KAZ Adding additional attributes for: KAZ
# KEN Adding additional attributes for: KEN
# KIR Adding additional attributes for: KIR
# XKO Adding additional attributes for: XKO
# KWT Adding additional attributes for: KWT
# KGZ Adding additional attributes for: KGZ
# LAO Adding additional attributes for: LAO
# LVA Adding additional attributes for: LVA
# LBN Adding additional attributes for: LBN
# LSO Adding additional attributes for: LSO
# LBR Adding additional attributes for: LBR
# LBY Adding additional attributes for: LBY
# LIE Adding additional attributes for: LIE
# LTU Adding additional attributes for: LTU
# LUX Adding additional attributes for: LUX
# MAC Adding additional attributes for: MAC
# MKD Adding additional attributes for: MKD
# MDG Adding additional attributes for: MDG
# MWI Adding additional attributes for: MWI
# MYS Adding additional attributes for: MYS
# MDV Adding additional attributes for: MDV
# MLI Adding additional attributes for: MLI
# MLT Adding additional attributes for: MLT
# MHL Adding additional attributes for: MHL
# MTQ Adding additional attributes for: MTQ
# MRT Adding additional attributes for: MRT
# MUS Adding additional attributes for: MUS
# MYT Adding additional attributes for: MYT
# MEX Adding additional attributes for: MEX
# FSM Adding additional attributes for: FSM
# MDA Adding additional attributes for: MDA
# MCO Adding additional attributes for: MCO
# MNG Adding additional attributes for: MNG
# MNE Adding additional attributes for: MNE
# MSR Adding additional attributes for: MSR
# MAR Adding additional attributes for: MAR
# MOZ Adding additional attributes for: MOZ
# MMR Adding additional attributes for: MMR
# NAM Adding additional attributes for: NAM
# NRU Adding additional attributes for: NRU
# NPL Adding additional attributes for: NPL
# NLD Adding additional attributes for: NLD
# NCL Adding additional attributes for: NCL
# NZL Adding additional attributes for: NZL
# NIC Adding additional attributes for: NIC
# NER Adding additional attributes for: NER
# NGA Adding additional attributes for: NGA
# NIU Adding additional attributes for: NIU
# NFK Adding additional attributes for: NFK
# PRK Adding additional attributes for: PRK
# XNC Adding additional attributes for: XNC
# MNP Adding additional attributes for: MNP
# NOR Adding additional attributes for: NOR
# OMN Adding additional attributes for: OMN
# PAK Adding additional attributes for: PAK
# PLW Adding additional attributes for: PLW
# PSE Adding additional attributes for: PSE
# PAN Adding additional attributes for: PAN
# PNG Adding additional attributes for: PNG
# XPI Adding additional attributes for: XPI
# PRY Adding additional attributes for: PRY
# PER Adding additional attributes for: PER
# PHL Adding additional attributes for: PHL
# PCN Adding additional attributes for: PCN
# POL Adding additional attributes for: POL
# PRT Adding additional attributes for: PRT
# PRI Adding additional attributes for: PRI
# QAT Adding additional attributes for: QAT
# COG Adding additional attributes for: COG
# REU Adding additional attributes for: REU
# ROU Adding additional attributes for: ROU
# RUS Adding additional attributes for: RUS
# RWA Adding additional attributes for: RWA
# SHN Adding additional attributes for: SHN
# KNA Adding additional attributes for: KNA
# LCA Adding additional attributes for: LCA
# SPM Adding additional attributes for: SPM
# VCT Adding additional attributes for: VCT
# BLM Adding additional attributes for: BLM
# MAF Adding additional attributes for: MAF
# WSM Adding additional attributes for: WSM
# SMR Adding additional attributes for: SMR
# STP Adding additional attributes for: STP
# SAU Adding additional attributes for: SAU
# SEN Adding additional attributes for: SEN
# SRB Adding additional attributes for: SRB
# SYC Adding additional attributes for: SYC
# SLE Adding additional attributes for: SLE
# SGP Adding additional attributes for: SGP
# SXM Adding additional attributes for: SXM
# SVK Adding additional attributes for: SVK
# SVN Adding additional attributes for: SVN
# SLB Adding additional attributes for: SLB
# SOM Adding additional attributes for: SOM
# ZAF Adding additional attributes for: ZAF
# SGS Adding additional attributes for: SGS
# KOR Adding additional attributes for: KOR
# SSD Adding additional attributes for: SSD
# ESP Adding additional attributes for: ESP
# XSP Adding additional attributes for: XSP
# LKA Adding additional attributes for: LKA
# SDN Adding additional attributes for: SDN
# SUR Adding additional attributes for: SUR
# SJM Adding additional attributes for: SJM
# SWZ Adding additional attributes for: SWZ
# SWE Adding additional attributes for: SWE
# CHE Adding additional attributes for: CHE
# SYR Adding additional attributes for: SYR
# TWN Adding additional attributes for: TWN
# TJK Adding additional attributes for: TJK
# TZA Adding additional attributes for: TZA
# THA Adding additional attributes for: THA
# TLS Adding additional attributes for: TLS
# TGO Adding additional attributes for: TGO
# TKL Adding additional attributes for: TKL
# TON Adding additional attributes for: TON
# TTO Adding additional attributes for: TTO
# TUN Adding additional attributes for: TUN
# TUR Adding additional attributes for: TUR
# TKM Adding additional attributes for: TKM
# TCA Adding additional attributes for: TCA
# TUV Adding additional attributes for: TUV
# UGA Adding additional attributes for: UGA
# UKR Adding additional attributes for: UKR
# ARE Adding additional attributes for: ARE
# GBR Adding additional attributes for: GBR
# USA Adding additional attributes for: USA
# UMI Adding additional attributes for: UMI
# UMI not available in service
# URY Adding additional attributes for: URY
# UZB Adding additional attributes for: UZB
# VUT Adding additional attributes for: VUT
# VEN Adding additional attributes for: VEN
# VNM Adding additional attributes for: VNM
# VIR Adding additional attributes for: VIR
# WLF Adding additional attributes for: WLF
# ESH Adding additional attributes for: ESH
# YEM Adding additional attributes for: YEM
# ZMB Adding additional attributes for: ZMB
# ZWE Adding additional attributes for: ZWE

# %%
flayer.edit_features(updates= features_for_update)
# Out:
# {'addResults': [],
#  'updateResults': [{'objectId': 2,
#    'uniqueId': 2,
#    'globalId': None,
#    'success': True},
#   {'objectId': 241, 'uniqueId': 241, 'globalId': None, 'success': True},
#   {'objectId': 5, 'uniqueId': 5, 'globalId': None, 'success': True},
#   {'objectId': 6, 'uniqueId': 6, 'globalId': None, 'success': True},
#   {'objectId': 65, 'uniqueId': 65, 'globalId': None, 'success': True},
#   {'objectId': 11, 'uniqueId': 11, 'globalId': None, 'success': True},
#   {'objectId': 7, 'uniqueId': 7, 'globalId': None, 'success': True},
#   {'objectId': 3, 'uniqueId': 3, 'globalId': None, 'success': True},
#   {'objectId': 4, 'uniqueId': 4, 'globalId': None, 'success': True},
#   {'objectId': 12, 'uniqueId': 12, 'globalId': None, 'success': True},
#   {'objectId': 14, 'uniqueId': 14, 'globalId': None, 'success': True},
#   {'objectId': 9, 'uniqueId': 9, 'globalId': None, 'success': True},
#   {'objectId': 10, 'uniqueId': 10, 'globalId': None, 'success': True},
# 3   AIA     Anguilla       83.30       0.16      84.47        125   0.10
# 4   ALA        Åland     1506.31       0.15       1.49        132  55.41

# %% [markdown]
# ## Prepare the service to have more fields with the total number of species

# %%
#Get the existing list of fields on the published feature layer
flayer_fields = flayer.manager.properties.fields

# %%
for field in flayer_fields:
    print(f"{field.name:13}|  {field.alias:13}|  {field.type:25}|  {field.sqlType}")
# Out:
# OBJECTID_1   |  OBJECTID_1   |  esriFieldTypeOID         |  sqlTypeOther
# GID_0        |  GID_0        |  esriFieldTypeString      |  sqlTypeOther
# NAME_0       |  NAME_0       |  esriFieldTypeString      |  sqlTypeOther
# jpg_url      |  jpg_url      |  esriFieldTypeString      |  sqlTypeOther
# OBJECTID     |  OBJECTID     |  esriFieldTypeInteger     |  sqlTypeOther
# GID          |  GID          |  esriFieldTypeString      |  sqlTypeOther
# Area         |  Area         |  esriFieldTypeInteger     |  sqlTypeOther
# GNI_PPP      |  GNI_PPP      |  esriFieldTypeDouble      |  sqlTypeOther
# Protected    |  Protected    |  esriFieldTypeInteger     |  sqlTypeOther
# HM_0         |  HM_0         |  esriFieldTypeInteger     |  sqlTypeOther
# HM_low       |  HM_low       |  esriFieldTypeInteger     |  sqlTypeOther
# HM_moderate  |  HM_moderate  |  esriFieldTypeInteger     |  sqlTypeOther
# HM_high      |  HM_high      |  esriFieldTypeInteger     |  sqlTypeOther
# Population2016|  SUM          |  esriFieldTypeDouble      |  sqlTypeOther
# max_amph     |  max_amph     |  esriFieldTypeInteger     |  sqlTypeOther
# max_bird     |  max_bird     |  esriFieldTypeInteger     |  sqlTypeOther
# max_mamm     |  max_mamm     |  esriFieldTypeInteger     |  sqlTypeOther
# max_rept     |  max_rept     |  esriFieldTypeInteger     |  sqlTypeOther
# max_cact     |  max_cact     |  esriFieldTypeInteger     |  sqlTypeOther
# max_coni     |  max_coni     |  esriFieldTypeInteger     |  sqlTypeOther
# max_all      |  max_all      |  esriFieldTypeInteger     |  sqlTypeOther
# sentence     |  sentence     |  esriFieldTypeString      |  sqlTypeOther
# prop_protected|  prop_protected|  esriFieldTypeDouble      |  sqlTypeOther
# gadm_prop_COUNT|  COUNT        |  esriFieldTypeInteger     |  sqlTypeOther
# N_SPECIES    |  N_SPECIES    |  esriFieldTypeInteger     |  sqlTypeOther
# SPI          |  SPI          |  esriFieldTypeDouble      |  sqlTypeOther
# amphibians   |  amphibians   |  esriFieldTypeInteger     |  sqlTypeOther
# birds        |  birds        |  esriFieldTypeInteger     |  sqlTypeOther
# mammals      |  mammals      |  esriFieldTypeInteger     |  sqlTypeOther
# nspecies     |  nspecies     |  esriFieldTypeInteger     |  sqlTypeOther
# reptiles     |  reptiles     |  esriFieldTypeInteger     |  sqlTypeOther
# total_endemic|  total_endemic|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_amphibians|  endemic_amphibians|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_birds|  endemic_birds|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_mammals|  endemic_mammals|  esriFieldTypeInteger     |  sqlTypeOther
# endemic_reptiles|  endemic_reptiles|  esriFieldTypeInteger     |  sqlTypeOther

# %%
template_field = dict(deepcopy(flayer_fields[7]))
template_field
# Out:
# {'name': 'GNI_PPP',
#  'type': 'esriFieldTypeDouble',
#  'alias': 'GNI_PPP',
#  'sqlType': 'sqlTypeOther',
#  'nullable': True,
#  'editable': True,
#  'visible': True,
#  'domain': None,
#  'defaultValue': None}

# %%
new_field_names = ['protection_needed']

# %%
fields_to_be_added = []
for new_field_name in new_field_names:
    current_field = deepcopy(template_field)
    if new_field_name.lower() == 'class':
        current_field['sqlType'] = 'sqlTypeVarchar'
        current_field['type'] = 'esriFieldTypeInteger'
        #current_field['length'] = 8000
    current_field['name'] = new_field_name.lower()
    current_field['alias'] = new_field_name
    fields_to_be_added.append(current_field)
    
len(fields_to_be_added)
# Out:
# 1

# %%
flayer.manager.add_to_definition({'fields':fields_to_be_added})
# Out:
# {'success': True}

# %%
new_fields = flayer.manager.properties.fields
len(new_fields)
# Out:
# 37

# %%
for field in new_fields:
    print(f"{field.name:10}|  {field.type}")
# Out:
# OBJECTID_1|  esriFieldTypeOID
# GID_0     |  esriFieldTypeString
# NAME_0    |  esriFieldTypeString
# jpg_url   |  esriFieldTypeString
# OBJECTID  |  esriFieldTypeInteger
# GID       |  esriFieldTypeString
# Area      |  esriFieldTypeInteger
# GNI_PPP   |  esriFieldTypeDouble
# Protected |  esriFieldTypeInteger
# HM_0      |  esriFieldTypeInteger
# HM_low    |  esriFieldTypeInteger
# HM_moderate|  esriFieldTypeInteger
# HM_high   |  esriFieldTypeInteger
# Population2016|  esriFieldTypeDouble
# max_amph  |  esriFieldTypeInteger
# max_bird  |  esriFieldTypeInteger
# max_mamm  |  esriFieldTypeInteger
# max_rept  |  esriFieldTypeInteger
# max_cact  |  esriFieldTypeInteger
# max_coni  |  esriFieldTypeInteger
# max_all   |  esriFieldTypeInteger
# sentence  |  esriFieldTypeString
# prop_protected|  esriFieldTypeDouble
# gadm_prop_COUNT|  esriFieldTypeInteger
# N_SPECIES |  esriFieldTypeInteger
# SPI       |  esriFieldTypeDouble
# amphibians|  esriFieldTypeInteger
# birds     |  esriFieldTypeInteger
# mammals   |  esriFieldTypeInteger
# nspecies  |  esriFieldTypeInteger
# reptiles  |  esriFieldTypeInteger
# total_endemic|  esriFieldTypeInteger
# endemic_amphibians|  esriFieldTypeInteger
# endemic_birds|  esriFieldTypeInteger
# endemic_mammals|  esriFieldTypeInteger
# endemic_reptiles|  esriFieldTypeInteger
# protection_needed|  esriFieldTypeDouble

# %% [markdown]
# ## Update the data in the new fields with the data from the csv of total number of species

# %%
fset2 = flayer.query()
features2 = fset2.features

# %%
features_for_update = []
for country_id in spi_df['GID_0']:
    try:
        # get the matching row from csv
        matching_row = spi_df.where(spi_df.GID_0 == country_id).dropna()

        print(str(country_id) + " Adding additional attributes for: " + matching_row['GID_0'].values[0])

        # get the feature to be updated
        assert  len([f for f in features2 if f.attributes['GID_0'] == country_id]),  "country not matched"
        original_feature = [f for f in features2 if f.attributes['GID_0'] == country_id][0]
        feature_to_be_updated = deepcopy(original_feature)

        # assign the updated values
        #print( matching_row['PERC_NEED'].values[0])
        feature_to_be_updated.attributes['protection_needed'] = matching_row['PERC_NEED'].values[0]

        #add this to the list of features to be updated
        
        features_for_update.append(feature_to_be_updated)
        #print(str(country_id) + " Done additional attributes for: " + matching_row['countryname'].values[0])
    except:
        print(f"{country_id} not available in service")
# Out:
# ABW Adding additional attributes for: ABW
# AFG Adding additional attributes for: AFG
# AGO Adding additional attributes for: AGO
# AIA Adding additional attributes for: AIA
# ALA Adding additional attributes for: ALA
# ALB Adding additional attributes for: ALB
# AND Adding additional attributes for: AND
# ARE Adding additional attributes for: ARE
# ARG Adding additional attributes for: ARG
# ARM Adding additional attributes for: ARM
# ASM Adding additional attributes for: ASM
# ATA Adding additional attributes for: ATA
# ATF Adding additional attributes for: ATF
# ATG Adding additional attributes for: ATG
# AUS Adding additional attributes for: AUS
# AUT Adding additional attributes for: AUT
# AZE Adding additional attributes for: AZE
# BDI Adding additional attributes for: BDI
# BEL Adding additional attributes for: BEL
# BEN Adding additional attributes for: BEN
# BES Adding additional attributes for: BES
# BFA Adding additional attributes for: BFA
# BGD Adding additional attributes for: BGD
# BGR Adding additional attributes for: BGR
# BHR Adding additional attributes for: BHR
# BHS Adding additional attributes for: BHS
# BIH Adding additional attributes for: BIH
# BLM Adding additional attributes for: BLM
# BLR Adding additional attributes for: BLR
# BLZ Adding additional attributes for: BLZ
# BMU Adding additional attributes for: BMU
# BOL Adding additional attributes for: BOL
# BRA Adding additional attributes for: BRA
# BRB Adding additional attributes for: BRB
# BRN Adding additional attributes for: BRN
# BTN Adding additional attributes for: BTN
# BVT Adding additional attributes for: BVT
# BWA Adding additional attributes for: BWA
# CAF Adding additional attributes for: CAF
# CAN Adding additional attributes for: CAN
# CCK Adding additional attributes for: CCK
# CHE Adding additional attributes for: CHE
# CHL Adding additional attributes for: CHL
# CHN Adding additional attributes for: CHN
# CIV Adding additional attributes for: CIV
# CMR Adding additional attributes for: CMR
# COD Adding additional attributes for: COD
# COG Adding additional attributes for: COG
# COK Adding additional attributes for: COK
# COL Adding additional attributes for: COL
# COM Adding additional attributes for: COM
# CPV Adding additional attributes for: CPV
# CRI Adding additional attributes for: CRI
# CUB Adding additional attributes for: CUB
# CUW Adding additional attributes for: CUW
# CXR Adding additional attributes for: CXR
# CYM Adding additional attributes for: CYM
# CYP Adding additional attributes for: CYP
# CZE Adding additional attributes for: CZE
# DEU Adding additional attributes for: DEU
# DJI Adding additional attributes for: DJI
# DMA Adding additional attributes for: DMA
# DNK Adding additional attributes for: DNK
# DOM Adding additional attributes for: DOM
# DZA Adding additional attributes for: DZA
# ECU Adding additional attributes for: ECU
# EGY Adding additional attributes for: EGY
# ERI Adding additional attributes for: ERI
# ESH Adding additional attributes for: ESH
# ESP Adding additional attributes for: ESP
# EST Adding additional attributes for: EST
# ETH Adding additional attributes for: ETH
# FIN Adding additional attributes for: FIN
# FJI Adding additional attributes for: FJI
# FLK Adding additional attributes for: FLK
# FRA Adding additional attributes for: FRA
# FRO Adding additional attributes for: FRO
# FSM Adding additional attributes for: FSM
# GAB Adding additional attributes for: GAB
# GBR Adding additional attributes for: GBR
# GEO Adding additional attributes for: GEO
# GGY Adding additional attributes for: GGY
# GHA Adding additional attributes for: GHA
# GIB Adding additional attributes for: GIB
# GIN Adding additional attributes for: GIN
# GLP Adding additional attributes for: GLP
# GMB Adding additional attributes for: GMB
# GNB Adding additional attributes for: GNB
# GNQ Adding additional attributes for: GNQ
# GRC Adding additional attributes for: GRC
# GRD Adding additional attributes for: GRD
# GRL Adding additional attributes for: GRL
# GTM Adding additional attributes for: GTM
# GUF Adding additional attributes for: GUF
# GUM Adding additional attributes for: GUM
# GUY Adding additional attributes for: GUY
# HKG Adding additional attributes for: HKG
# HMD Adding additional attributes for: HMD
# HND Adding additional attributes for: HND
# HRV Adding additional attributes for: HRV
# HTI Adding additional attributes for: HTI
# HUN Adding additional attributes for: HUN
# IDN Adding additional attributes for: IDN
# IMN Adding additional attributes for: IMN
# IND Adding additional attributes for: IND
# IOT Adding additional attributes for: IOT
# IOT not available in service
# IRL Adding additional attributes for: IRL
# IRN Adding additional attributes for: IRN
# IRQ Adding additional attributes for: IRQ
# ISL Adding additional attributes for: ISL
# ISR Adding additional attributes for: ISR
# ITA Adding additional attributes for: ITA
# JAM Adding additional attributes for: JAM
# JEY Adding additional attributes for: JEY
# JOR Adding additional attributes for: JOR
# JPN Adding additional attributes for: JPN
# KAZ Adding additional attributes for: KAZ
# KEN Adding additional attributes for: KEN
# KGZ Adding additional attributes for: KGZ
# KHM Adding additional attributes for: KHM
# KIR Adding additional attributes for: KIR
# KNA Adding additional attributes for: KNA
# KOR Adding additional attributes for: KOR
# KWT Adding additional attributes for: KWT
# LAO Adding additional attributes for: LAO
# LBN Adding additional attributes for: LBN
# LBR Adding additional attributes for: LBR
# LBY Adding additional attributes for: LBY
# LCA Adding additional attributes for: LCA
# LIE Adding additional attributes for: LIE
# LKA Adding additional attributes for: LKA
# LSO Adding additional attributes for: LSO
# LTU Adding additional attributes for: LTU
# LUX Adding additional attributes for: LUX
# LVA Adding additional attributes for: LVA
# MAC Adding additional attributes for: MAC
# MAF Adding additional attributes for: MAF
# MAR Adding additional attributes for: MAR
# MCO Adding additional attributes for: MCO
# MDA Adding additional attributes for: MDA
# MDG Adding additional attributes for: MDG
# MDV Adding additional attributes for: MDV
# MEX Adding additional attributes for: MEX
# MHL Adding additional attributes for: MHL
# MKD Adding additional attributes for: MKD
# MLI Adding additional attributes for: MLI
# MLT Adding additional attributes for: MLT
# MMR Adding additional attributes for: MMR
# MNE Adding additional attributes for: MNE
# MNG Adding additional attributes for: MNG
# MNP Adding additional attributes for: MNP
# MOZ Adding additional attributes for: MOZ
# MRT Adding additional attributes for: MRT
# MSR Adding additional attributes for: MSR
# MTQ Adding additional attributes for: MTQ
# MUS Adding additional attributes for: MUS
# MWI Adding additional attributes for: MWI
# MYS Adding additional attributes for: MYS
# MYT Adding additional attributes for: MYT
# NAM Adding additional attributes for: NAM
# NCL Adding additional attributes for: NCL
# NER Adding additional attributes for: NER
# NFK Adding additional attributes for: NFK
# NGA Adding additional attributes for: NGA
# NIC Adding additional attributes for: NIC
# NIU Adding additional attributes for: NIU
# NLD Adding additional attributes for: NLD
# NOR Adding additional attributes for: NOR
# NPL Adding additional attributes for: NPL
# NRU Adding additional attributes for: NRU
# NZL Adding additional attributes for: NZL
# OMN Adding additional attributes for: OMN
# PAK Adding additional attributes for: PAK
# PAN Adding additional attributes for: PAN
# PCN Adding additional attributes for: PCN
# PER Adding additional attributes for: PER
# PHL Adding additional attributes for: PHL
# PLW Adding additional attributes for: PLW
# PNG Adding additional attributes for: PNG
# POL Adding additional attributes for: POL
# PRI Adding additional attributes for: PRI
# PRK Adding additional attributes for: PRK
# PRT Adding additional attributes for: PRT
# PRY Adding additional attributes for: PRY
# PSE Adding additional attributes for: PSE
# PYF Adding additional attributes for: PYF
# QAT Adding additional attributes for: QAT
# REU Adding additional attributes for: REU
# ROU Adding additional attributes for: ROU
# RUS Adding additional attributes for: RUS
# RWA Adding additional attributes for: RWA
# SAU Adding additional attributes for: SAU
# SDN Adding additional attributes for: SDN
# SEN Adding additional attributes for: SEN
# SGP Adding additional attributes for: SGP
# SGS Adding additional attributes for: SGS
# SHN Adding additional attributes for: SHN
# SJM Adding additional attributes for: SJM
# SLB Adding additional attributes for: SLB
# SLE Adding additional attributes for: SLE
# SLV Adding additional attributes for: SLV
# SMR Adding additional attributes for: SMR
# SOM Adding additional attributes for: SOM
# SPM Adding additional attributes for: SPM
# SRB Adding additional attributes for: SRB
# SSD Adding additional attributes for: SSD
# STP Adding additional attributes for: STP
# SUR Adding additional attributes for: SUR
# SVK Adding additional attributes for: SVK
# SVN Adding additional attributes for: SVN
# SWE Adding additional attributes for: SWE
# SWZ Adding additional attributes for: SWZ
# SXM Adding additional attributes for: SXM
# SYC Adding additional attributes for: SYC
# SYR Adding additional attributes for: SYR
# TCA Adding additional attributes for: TCA
# TCD Adding additional attributes for: TCD
# TGO Adding additional attributes for: TGO
# THA Adding additional attributes for: THA
# TJK Adding additional attributes for: TJK
# TKL Adding additional attributes for: TKL
# TKM Adding additional attributes for: TKM
# TLS Adding additional attributes for: TLS
# TON Adding additional attributes for: TON
# TTO Adding additional attributes for: TTO
# TUN Adding additional attributes for: TUN
# TUR Adding additional attributes for: TUR
# TUV Adding additional attributes for: TUV
# TWN Adding additional attributes for: TWN
# TZA Adding additional attributes for: TZA
# UGA Adding additional attributes for: UGA
# UKR Adding additional attributes for: UKR
# UMI Adding additional attributes for: UMI
# UMI not available in service
# URY Adding additional attributes for: URY
# USA Adding additional attributes for: USA
# UZB Adding additional attributes for: UZB
# VCT Adding additional attributes for: VCT
# VEN Adding additional attributes for: VEN
# VGB Adding additional attributes for: VGB
#   {'objectId': 237, 'uniqueId': 237, 'globalId': None, 'success': True},
#   {'objectId': 238, 'uniqueId': 238, 'globalId': None, 'success': True},
#   {'objectId': 239, 'uniqueId': 239, 'globalId': None, 'success': True},
#   {'objectId': 240, 'uniqueId': 240, 'globalId': None, 'success': True},
#   {'objectId': 241, 'uniqueId': 241, 'globalId': None, 'success': True},
#   {'objectId': 242, 'uniqueId': 242, 'globalId': None, 'success': True},
#   {'objectId': 243, 'uniqueId': 243, 'globalId': None, 'success': True},
#   {'objectId': 244, 'uniqueId': 244, 'globalId': None, 'success': True},
#   {'objectId': 245, 'uniqueId': 245, 'globalId': None, 'success': True},
#   {'objectId': 252, 'uniqueId': 252, 'globalId': None, 'success': True},
#   {'objectId': 246, 'uniqueId': 246, 'globalId': None, 'success': True},
#   {'objectId': 247, 'uniqueId': 247, 'globalId': None, 'success': True},
#   {'objectId': 248, 'uniqueId': 248, 'globalId': None, 'success': True},
#   {'objectId': 249, 'uniqueId': 249, 'globalId': None, 'success': True}],
#  'deleteResults': []}

# %% [markdown]
# # Making a function

# %%
import arcgis
from arcgis.gis import GIS, GroupManager
from arcgis.features import FeatureLayerCollection
from arcgis.features import FeatureLayer
from copy import deepcopy
from arcgis import geometry
import re
from pprint import pprint
import pandas as pd

# %%
env_path = ".env"
with open(env_path) as f:
    env = {}
    for line in f:
        env_key, _val = line.split("=")
        env_value = _val.split("\n")[0]
        env[env_key] = env_value

# %%
aol_password = env['aol_key']
aol_username = env['aol_username']

# %%
#gis = GIS("https://eowilson.maps.arcgis.com", aol_username, aol_password, profile = "eowilson")

# %%
gis = GIS(profile = "eowilson")

# %%
def create_strict_reg_exp(to_search):
    try:
        reg_exp = f"^{to_search}$"
        #logging.info(f"regular expression is: {reg_exp}")
    except:
        print("There was a problem with the string.")
    return reg_exp

# %%
def findItemGetID(csvName, gis):
    try:
        searched_item = gis.content.search(csvName, item_type = "Feature Layer")
        for i in searched_item:
            reg_exp = create_strict_reg_exp(csvName)
            if re.search(reg_exp, i.title)!= None:    
                #logging.info(f"{csvName} has the id: {i.id}")
                return i.id
    except:
        print("There was a problem finding the item")

# %%
def getFlayerFromID(item_id):
    item = gis.content.get(item_id)
    flayer = item.layers[0]
    return flayer

# %%
def getSDFfromFlayer(flayer):
    sdf = pd.DataFrame.spatial.from_layer(flayer)
    return sdf

# %%
def createFieldsToBeAdded(flayer, csv_table):
    flayer_fields = flayer.manager.properties.fields
    template_field = dict(deepcopy(flayer_fields[0]))
    sdf = getSDFfromFlayer(flayer)
    new_field_names = list(csv_table.columns.difference(sdf.columns))
    
    fields_to_be_added = []
    for new_field_name in new_field_names:
        current_field = deepcopy(template_field)
        dt = csv_table[new_field_name].dtypes
        
        if dt == 'O':
            #put the type to character
            current_field['sqlType'] = 'sqlTypeOther'
            current_field['type'] = 'esriFieldTypeString'
            #current_field['length'] = 8000
        if dt == 'float64':
            #put the type to double
            current_field['sqlType'] = 'sqlTypeOther'
            current_field['type'] = 'esriFieldTypeDouble'
            #current_field['length'] = 8000      

        current_field['name'] = new_field_name.lower()
        current_field['alias'] = new_field_name
        current_field['nullable'] = True
        current_field['editable'] = True
        fields_to_be_added.append(current_field)
    return fields_to_be_added

# %%
def createFeaturesForUpdate(flayer, csv_table, fields_to_be_added, id_field_in_csv, id_field_in_service):
    fset2 = flayer.query()
    features2 = fset2.features
    features_for_update = []
    for country_id in csv_table[id_field_in_csv]:
        try:
            # get the matching row from csv
            matching_row = csv_table.where(csv_table[id_field_in_csv] == country_id).dropna()

            #print(str(country_id) + " Adding additional attributes for: " + matching_row['iso3'].values[0])

            # get the feature to be updated
            assert  len([f for f in features2 if f.attributes[id_field_in_service] == country_id]),  "id not matched"
            original_feature = [f for f in features2 if f.attributes[id_field_in_service] == country_id][0]
            feature_to_be_updated = deepcopy(original_feature)

            # assign the updated values
            for field in fields_to_be_added:
                feature_to_be_updated.attributes[field['name']] = matching_row[field['name']].values[0]
                #add this to the list of features to be updated
                features_for_update.append(feature_to_be_updated)
            #print(str(country_id) + " Done additional attributes for: " + matching_row['countryname'].values[0])
    
        except:
            print(f"{country_id} not available in service")
    return features_for_update

# %%
item_id = findItemGetID("gadm_centroid", gis)

# %%
flayer = getFlayerFromID(item_id)

# %%
csv_table = pd.read_csv("/Users/gretacvega/Desktop/svg_test.csv")

# %%
csv_table
# Out:
#   GID_0                                                svg
# 0   USA  <svg xmlns="http://www.w3.org/2000/svg" xmlns:...

# %%
fields_to_be_added = createFieldsToBeAdded(flayer, csv_table)

# %%
flayer.manager.add_to_definition({'fields':fields_to_be_added})
# Out:
# {'success': True}

# %%
features_for_update = createFeaturesForUpdate(flayer, csv_table, fields_to_be_added, id_field_in_csv = "GID_0", id_field_in_service = "GID_0")

# %%
flayer.edit_features(updates= features_for_update)
# Out:
# Field svg has invalid html content.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-65-16708d7f1f30> in <module>
# ----> 1 flayer.edit_features(updates= features_for_update)
#
# /opt/anaconda3/lib/python3.7/site-packages/arcgis/features/layer.py in edit_features(self, adds, updates, deletes, gdb_version, use_global_ids, rollback_on_failure)
#    1323             print("Parameters not valid for edit_features")
#    1324             return None
# -> 1325         return self._con.post(path=edit_url, postdata=params, token=self._token)
#    1326
#    1327     # ----------------------------------------------------------------------
#
# /opt/anaconda3/lib/python3.7/site-packages/arcgis/_impl/connection.py in post(self, path, postdata, files, ssl, compress, is_retry, use_ordered_dict, add_token, verify_cert, token, try_json, out_folder, file_name, force_bytes, add_headers)
#    1157                                          verify_cert=verify_cert, is_retry=True)
#    1158
# -> 1159                 self._handle_json_error(resp_json['error'], errorcode)
#    1160                 return None
#    1161
#
# /opt/anaconda3/lib/python3.7/site-packages/arcgis/_impl/connection.py in _handle_json_error(self, error, errorcode)
#    1178
#    1179         errormessage = errormessage + "\n(Error Code: " + str(errorcode) +")"
# -> 1180         raise RuntimeError(errormessage)
#    1181
#    1182 class _StrictURLopener(request.FancyURLopener):
#
# RuntimeError:
# Field svg has invalid html content.
# (Error Code: 400)
